# %%
import gymnasium   #
import CoppeliaSim_Gym   # Entorno personalizado
import stable_baselines3   # Biblioteca RL
from stable_baselines3 import A2C, PPO
from matplotlib import pyplot as plt 
import pandas as pd
import numpy as np
import seaborn as sns
# Inicializar el entorno
ENV_NAME = "CoppeliaSim_Gym/GymCoppManR-v0"
env = gymnasium.make(ENV_NAME)

model = A2C.load("modeloA2C", env=env)
model.policy
ep_reward = 0
# Evaluar el modelo entrenado
val = []
X_ = []
Y_ = []
obs, inf = env.reset()
print('obs', obs.shape)
for episode in range(100):
    env.render()
    action, state = model.predict(obs, deterministic=False) # ,deterministic=True
    n_obs, reward, done, tru, info = env.step(action)
    #print(f'Obs: {obs} reward: {reward} done: {done} info: {info}')
    print(f'Acciones: {action} Estado: {state} Recompensa: {reward} Info: {info}')
    ep_reward += reward
    obs = n_obs
    val += [reward]
    X_.append(episode)
    Y_.append(np.array(val).mean())
plt.plot(X_, Y_)
plt.title('Acumulated reward')
plt.xlabel('Episodes')
plt.ylabel('Reward')
plt.show() 
env.close()
# Out:
# Conectado al servidor API remoto
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# obs (18,)
# Contador:  1
# Distancia previa : 0.467 m
# Distancia actual: 0.467 m
# Recompensa Distancia: -0.467
# Recompensa Costo: -0.3270415782928467
# Recompensa diferencia: 0.001
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.7930164870169626
# --------------------------------------------------------------------
# Acciones: [-1.         -0.51754844 -1.         -0.2608041  -0.51108426 -0.8126255
#  -0.11390074] Estado: None Recompensa: -0.7930164870169626 Info: {'info': array(0.46652916, dtype=float32)}
# Contador:  2
# Distancia previa : 0.467 m
# Distancia actual: 0.462 m
# Recompensa Distancia: -0.462
# Recompensa Costo: -0.2730667352676392
# Recompensa diferencia: 0.005
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.7299338703731422
# --------------------------------------------------------------------
# Acciones: [ 0.6928099  -0.15107174 -1.         -0.46612325  0.09957741 -0.0259332
#  -1.        ] Estado: None Recompensa: -0.7299338703731422 Info: {'info': array(0.46169814, dtype=float32)}
# Contador:  3
# Distancia previa : 0.462 m
# Distancia actual: 0.471 m
# Recompensa Distancia: -0.471
# Recompensa Costo: -0.49999446868896485
# Recompensa diferencia: -0.009
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.9805850097505502
# --------------------------------------------------------------------
# Acciones: [-0.99397564 -0.22337808  1.          1.         -1.          0.9806443
#   0.0199017 ] Estado: None Recompensa: -0.9805850097505502 Info: {'info': array(0.47114435, dtype=float32)}
# Contador:  4
# Distancia previa : 0.471 m
# Distancia actual: 0.465 m
# Recompensa Distancia: -0.465
# Recompensa Costo: -0.3796268463134766
# Recompensa diferencia: 0.006
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.8379245525744228
# --------------------------------------------------------------------
# Acciones: [-0.9293982  -0.2886243   1.         -0.7024451  -0.5438881  -0.5992341
#   0.83717304] Estado: None Recompensa: -0.8379245525744228 Info: {'info': array(0.46472102, dtype=float32)}
# Contador:  5
# Distancia previa : 0.465 m
# Distancia actual: 0.449 m
# Recompensa Distancia: -0.449
# Recompensa Costo: -0.2665837049484253
# Recompensa diferencia: 0.016
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.7002491577471918
# --------------------------------------------------------------------
# Acciones: [-0.4958559   0.5578956   1.         -0.8305496  -0.48563737 -0.427654
#   0.01311966] Estado: None Recompensa: -0.7002491577471918 Info: {'info': array(0.44919324, dtype=float32)}
# Contador:  6
# Distancia previa : 0.449 m
# Distancia actual: 0.459 m
# Recompensa Distancia: -0.459
# Recompensa Costo: -0.4449919223785401
# Recompensa diferencia: -0.010
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.9138221812554705
# --------------------------------------------------------------------
# Acciones: [-1.         -0.6210593   1.          1.          0.24586232 -1.
#   0.06129144] Estado: None Recompensa: -0.9138221812554705 Info: {'info': array(0.45901173, dtype=float32)}
# Contador:  7
# Distancia previa : 0.459 m
# Distancia actual: 0.439 m
# Recompensa Distancia: -0.439
# Recompensa Costo: -0.6916180610656739
# Recompensa diferencia: 0.020
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -1.110558399768411
# --------------------------------------------------------------------
# Acciones: [ 1.          1.          1.         -1.          0.95717335  1.
#  -1.        ] Estado: None Recompensa: -1.110558399768411 Info: {'info': array(0.43897602, dtype=float32)}
# Contador:  8
# Distancia previa : 0.439 m
# Distancia actual: 0.435 m
# Recompensa Distancia: -0.435
# Recompensa Costo: -0.22021017074584961
# Recompensa diferencia: 0.003
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.6522250553538596
# --------------------------------------------------------------------
# Acciones: [ 0.11759339  0.13576129 -0.18422309  0.18463138 -1.         -0.7188554
#   0.7648937 ] Estado: None Recompensa: -0.6522250553538596 Info: {'info': array(0.43549547, dtype=float32)}
# Contador:  9
# Distancia previa : 0.435 m
# Distancia actual: 0.424 m
# Recompensa Distancia: -0.424
# Recompensa Costo: -0.24091131687164308
# Recompensa diferencia: 0.011
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.6540656707030121
# --------------------------------------------------------------------
# Acciones: [ 0.47217155  0.26159322  0.5310979  -0.6196884   1.         -0.652249
#  -0.1619536 ] Estado: None Recompensa: -0.6540656707030121 Info: {'info': array(0.4243249, dtype=float32)}
# Contador:  10
# Distancia previa : 0.424 m
# Distancia actual: 0.418 m
# Recompensa Distancia: -0.418
# Recompensa Costo: -0.2123576641082764
# Recompensa diferencia: 0.007
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.6230539165931399
# --------------------------------------------------------------------
# Acciones: [-0.43904948 -0.12194821 -0.5924846  -0.6174101  -1.         -0.39127722
#   0.17495587] Estado: None Recompensa: -0.6230539165931399 Info: {'info': array(0.41751057, dtype=float32)}
# Contador:  11
# Distancia previa : 0.418 m
# Distancia actual: 0.410 m
# Recompensa Distancia: -0.410
# Recompensa Costo: -0.48005023002624514
# Recompensa diferencia: 0.007
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.8828154164183692
# --------------------------------------------------------------------
# Acciones: [-1.          1.          1.          0.62343097  1.          0.5626544
#  -0.3086361 ] Estado: None Recompensa: -0.8828154164183692 Info: {'info': array(0.41013786, dtype=float32)}
# Contador:  12
# Distancia previa : 0.410 m
# Distancia actual: 0.401 m
# Recompensa Distancia: -0.401
# Recompensa Costo: -0.27481372356414796
# Recompensa diferencia: 0.009
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.6664412082965327
# --------------------------------------------------------------------
# Acciones: [ 0.903684    0.38388032 -0.88400507 -0.2605828  -0.42241466 -0.6341852
#   0.59509254] Estado: None Recompensa: -0.6664412082965327 Info: {'info': array(0.40088266, dtype=float32)}
# Contador:  13
# Distancia previa : 0.401 m
# Distancia actual: 0.402 m
# Recompensa Distancia: -0.402
# Recompensa Costo: -0.22710528373718264
# Recompensa diferencia: -0.001
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.6294406572570612
# --------------------------------------------------------------------
# Acciones: [-0.27255264 -0.47384885  0.93729377 -0.18194126 -0.57055694  0.7084843
#  -0.4828331 ] Estado: None Recompensa: -0.6294406572570612 Info: {'info': array(0.401609, dtype=float32)}
# Contador:  14
# Distancia previa : 0.402 m
# Distancia actual: 0.396 m
# Recompensa Distancia: -0.396
# Recompensa Costo: -0.2741467237472534
# Recompensa diferencia: 0.005
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.6648642728203691
# --------------------------------------------------------------------
# Acciones: [ 0.06007445 -0.28656474 -0.8334463  -0.71312404 -0.66776216  0.08157237
#   1.        ] Estado: None Recompensa: -0.6648642728203691 Info: {'info': array(0.39616328, dtype=float32)}
# Contador:  15
# Distancia previa : 0.396 m
# Distancia actual: 0.401 m
# Recompensa Distancia: -0.401
# Recompensa Costo: -0.4212957382202149
# Recompensa diferencia: -0.005
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.8279245094289673
# --------------------------------------------------------------------
# Acciones: [ 1.         -1.         -0.32392752 -0.26279864  0.19739547  1.
#   1.        ] Estado: None Recompensa: -0.8279245094289673 Info: {'info': array(0.401396, dtype=float32)}
# Contador:  16
# Distancia previa : 0.401 m
# Distancia actual: 0.387 m
# Recompensa Distancia: -0.387
# Recompensa Costo: -0.3324238538742066
# Recompensa diferencia: 0.014
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.7057136769099841
# --------------------------------------------------------------------
# Acciones: [ 0.9513836   1.         -0.12438609 -0.18821806  0.5968604   0.10939561
#  -1.        ] Estado: None Recompensa: -0.7057136769099841 Info: {'info': array(0.38734293, dtype=float32)}
# Contador:  17
# Distancia previa : 0.387 m
# Distancia actual: 0.370 m
# Recompensa Distancia: -0.370
# Recompensa Costo: -0.338434100151062
# Recompensa diferencia: 0.017
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.6915070962449434
# --------------------------------------------------------------------
# Acciones: [-0.1421264   1.         -0.50426394 -0.5091405   1.         -0.72102624
#  -0.5751138 ] Estado: None Recompensa: -0.6915070962449434 Info: {'info': array(0.37020794, dtype=float32)}
# Contador:  18
# Distancia previa : 0.370 m
# Distancia actual: 0.354 m
# Recompensa Distancia: -0.354
# Recompensa Costo: -0.31640441417694093
# Recompensa diferencia: 0.016
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.6541876160619337
# --------------------------------------------------------------------
# Acciones: [ 0.14416066  1.          0.70199466 -0.47288674  0.26808834 -0.5957952
#  -1.        ] Estado: None Recompensa: -0.6541876160619337 Info: {'info': array(0.35399556, dtype=float32)}
# Contador:  19
# Distancia previa : 0.354 m
# Distancia actual: 0.356 m
# Recompensa Distancia: -0.356
# Recompensa Costo: -0.2355959177017212
# Recompensa diferencia: -0.002
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.59268812672096
# --------------------------------------------------------------------
# Acciones: [-0.3407856  -0.2462637   1.          0.33170098  0.02094803 -1.
#   0.26213416] Estado: None Recompensa: -0.59268812672096 Info: {'info': array(0.35554388, dtype=float32)}
# Contador:  20
# Distancia previa : 0.356 m
# Distancia actual: 0.348 m
# Recompensa Distancia: -0.348
# Recompensa Costo: -0.5611685276031494
# Recompensa diferencia: 0.007
# Recompensa llegada: 0.348417188891877
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.5540418211825696
# --------------------------------------------------------------------
# Acciones: [-0.7901323   1.          1.          0.7471469   0.9441783  -0.73326325
#   1.        ] Estado: None Recompensa: -0.5540418211825696 Info: {'info': array(0.34841716, dtype=float32)}
# Contador:  21
# Distancia previa : 0.348 m
# Distancia actual: 0.349 m
# Recompensa Distancia: -0.349
# Recompensa Costo: -0.48397283554077153
# Recompensa diferencia: -0.000
# Recompensa llegada: 0.34890569815472855
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.48446134480362296
# --------------------------------------------------------------------
# Acciones: [-1.          0.23285359 -0.2458186   0.89181924 -1.          0.96422994
#  -1.        ] Estado: None Recompensa: -0.48446134480362296 Info: {'info': array(0.34890568, dtype=float32)}
# Contador:  22
# Distancia previa : 0.349 m
# Distancia actual: 0.336 m
# Recompensa Distancia: -0.336
# Recompensa Costo: -0.3568393707275391
# Recompensa diferencia: 0.013
# Recompensa llegada: 0.33638037452115116
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3443140470939617
# --------------------------------------------------------------------
# Acciones: [ 1.          1.         -0.29648525  0.05874707  0.3758387  -1.
#  -0.579469  ] Estado: None Recompensa: -0.3443140470939617 Info: {'info': array(0.33638036, dtype=float32)}
# Contador:  23
# Distancia previa : 0.336 m
# Distancia actual: 0.341 m
# Recompensa Distancia: -0.341
# Recompensa Costo: -0.18600432872772218
# Recompensa diferencia: -0.004
# Recompensa llegada: 0.34064406879590337
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.19026802300247447
# --------------------------------------------------------------------
# Acciones: [ 1.         -0.54975766 -0.02769876  0.2700153  -0.17602663 -0.39082924
#  -0.54808897] Estado: None Recompensa: -0.19026802300247447 Info: {'info': array(0.34064406, dtype=float32)}
# Contador:  24
# Distancia previa : 0.341 m
# Distancia actual: 0.336 m
# Recompensa Distancia: -0.336
# Recompensa Costo: -0.22424540519714356
# Recompensa diferencia: 0.005
# Recompensa llegada: 0.33579282332599825
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.2193941597272384
# --------------------------------------------------------------------
# Acciones: [-0.3754876   0.76888645 -0.14291486  0.8709043  -0.2963259   0.21036695
#   0.77415395] Estado: None Recompensa: -0.2193941597272384 Info: {'info': array(0.3357928, dtype=float32)}
# Contador:  25
# Distancia previa : 0.336 m
# Distancia actual: 0.330 m
# Recompensa Distancia: -0.330
# Recompensa Costo: -0.3027513980865479
# Recompensa diferencia: 0.006
# Recompensa llegada: 0.3298672592047064
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.29682583396525597
# --------------------------------------------------------------------
# Acciones: [-0.15507819  0.8516225   0.12686701  0.75277585  0.6297282   0.54669875
#   1.        ] Estado: None Recompensa: -0.29682583396525597 Info: {'info': array(0.32986724, dtype=float32)}
# Contador:  26
# Distancia previa : 0.330 m
# Distancia actual: 0.328 m
# Recompensa Distancia: -0.328
# Recompensa Costo: -0.4340396881103516
# Recompensa diferencia: 0.002
# Recompensa llegada: 0.32776354989037665
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.4319359787960219
# --------------------------------------------------------------------
# Acciones: [ 0.38054156 -0.79012764  0.5924684  -1.          0.6183182  -0.9304902
#   0.985969  ] Estado: None Recompensa: -0.4319359787960219 Info: {'info': array(0.32776353, dtype=float32)}
# Contador:  27
# Distancia previa : 0.328 m
# Distancia actual: 0.328 m
# Recompensa Distancia: -0.328
# Recompensa Costo: -0.3738191604614258
# Recompensa diferencia: -0.000
# Recompensa llegada: 0.3280747670273616
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.37413037759841083
# --------------------------------------------------------------------
# Acciones: [ 0.5087386  -1.         -0.49424002 -0.8880415   0.4838791   0.7271329
#  -0.82681596] Estado: None Recompensa: -0.37413037759841083 Info: {'info': array(0.32807475, dtype=float32)}
# Contador:  28
# Distancia previa : 0.328 m
# Distancia actual: 0.327 m
# Recompensa Distancia: -0.327
# Recompensa Costo: -0.3350127220153809
# Recompensa diferencia: 0.001
# Recompensa llegada: 0.3269017399945137
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.33383969498253313
# --------------------------------------------------------------------
# Acciones: [ 0.62472093 -0.63762426 -0.2138659  -0.71216947  1.         -1.
#  -0.01903504] Estado: None Recompensa: -0.33383969498253313 Info: {'info': array(0.32690173, dtype=float32)}
# Contador:  29
# Distancia previa : 0.327 m
# Distancia actual: 0.328 m
# Recompensa Distancia: -0.328
# Recompensa Costo: -0.2534968376159668
# Recompensa diferencia: -0.001
# Recompensa llegada: 0.3283691027588442
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.25496420038029727
# --------------------------------------------------------------------
# Acciones: [-1.         -0.26211402  0.3316407   0.40557647  0.3391593  -0.2770515
#  -1.        ] Estado: None Recompensa: -0.25496420038029727 Info: {'info': array(0.32836908, dtype=float32)}
# Contador:  30
# Distancia previa : 0.328 m
# Distancia actual: 0.319 m
# Recompensa Distancia: -0.319
# Recompensa Costo: -0.33876297473907474
# Recompensa diferencia: 0.009
# Recompensa llegada: 0.3190651051841143
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.32945897716434486
# --------------------------------------------------------------------
# Acciones: [ 0.93905     0.20551673 -0.08096247 -0.6770952  -1.         -0.35688135
#   0.93338126] Estado: None Recompensa: -0.32945897716434486 Info: {'info': array(0.3190651, dtype=float32)}
# Contador:  31
# Distancia previa : 0.319 m
# Distancia actual: 0.305 m
# Recompensa Distancia: -0.305
# Recompensa Costo: -0.3036290407180786
# Recompensa diferencia: 0.014
# Recompensa llegada: 0.3050681853613565
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.28963212089532087
# --------------------------------------------------------------------
# Acciones: [-0.6323348   0.5687829  -1.         -0.61404103  0.12253623 -0.12389694
#   0.95158666] Estado: None Recompensa: -0.28963212089532087 Info: {'info': array(0.30506817, dtype=float32)}
# Contador:  32
# Distancia previa : 0.305 m
# Distancia actual: 0.289 m
# Recompensa Distancia: -0.289
# Recompensa Costo: -0.37088000774383545
# Recompensa diferencia: 0.016
# Recompensa llegada: 0.28898499806149686
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3547968204439758
# --------------------------------------------------------------------
# Acciones: [-0.5730434   0.7024747  -1.         -1.         -0.03662625 -0.9363505
#   0.09411091] Estado: None Recompensa: -0.3547968204439758 Info: {'info': array(0.28898498, dtype=float32)}
# Contador:  33
# Distancia previa : 0.289 m
# Distancia actual: 0.289 m
# Recompensa Distancia: -0.289
# Recompensa Costo: -0.2349862098693848
# Recompensa diferencia: 0.000
# Recompensa llegada: 0.28894524194060994
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.23494645374849782
# --------------------------------------------------------------------
# Acciones: [-0.16373017 -0.6475129   0.70550346 -0.56718343 -0.42963722 -0.37396327
#  -0.8717298 ] Estado: None Recompensa: -0.23494645374849782 Info: {'info': array(0.28894523, dtype=float32)}
# Contador:  34
# Distancia previa : 0.289 m
# Distancia actual: 0.287 m
# Recompensa Distancia: -0.287
# Recompensa Costo: -0.1781928062438965
# Recompensa diferencia: 0.002
# Recompensa llegada: 0.28686542407070953
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.17611298837399608
# --------------------------------------------------------------------
# Acciones: [-0.6867841  -0.10869548  0.5007982  -0.10796599 -0.47599822 -0.7647228
#   0.47393054] Estado: None Recompensa: -0.17611298837399608 Info: {'info': array(0.2868654, dtype=float32)}
# Contador:  35
# Distancia previa : 0.287 m
# Distancia actual: 0.282 m
# Recompensa Distancia: -0.282
# Recompensa Costo: -0.28299076557159425
# Recompensa diferencia: 0.005
# Recompensa llegada: 0.2815409947110903
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.2776663362119749
# --------------------------------------------------------------------
# Acciones: [ 1.          0.6276797   1.          0.27885318 -0.1712681  -0.49968573
#  -0.28133276] Estado: None Recompensa: -0.2776663362119749 Info: {'info': array(0.281541, dtype=float32)}
# Contador:  36
# Distancia previa : 0.282 m
# Distancia actual: 0.276 m
# Recompensa Distancia: -0.276
# Recompensa Costo: -0.515997314453125
# Recompensa diferencia: 0.005
# Recompensa llegada: 0.2761952136165804
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.5106515333586151
# --------------------------------------------------------------------
# Acciones: [-0.8770302   1.          0.7250051   1.          1.         -0.52982306
#   0.7644911 ] Estado: None Recompensa: -0.5106515333586151 Info: {'info': array(0.2761952, dtype=float32)}
# Contador:  37
# Distancia previa : 0.276 m
# Distancia actual: 0.288 m
# Recompensa Distancia: -0.288
# Recompensa Costo: -0.4507010936737061
# Recompensa diferencia: -0.011
# Recompensa llegada: 0.28763424903068713
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.4621401290878129
# --------------------------------------------------------------------
# Acciones: [ 1.         -1.          0.09442115  1.         -0.4026786   1.
#   0.579608  ] Estado: None Recompensa: -0.4621401290878129 Info: {'info': array(0.28763422, dtype=float32)}
# Contador:  38
# Distancia previa : 0.288 m
# Distancia actual: 0.274 m
# Recompensa Distancia: -0.274
# Recompensa Costo: -0.22250916957855227
# Recompensa diferencia: 0.014
# Recompensa llegada: 0.2738750225296275
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.20874994307749262
# --------------------------------------------------------------------
# Acciones: [ 0.13461173  0.58151585  0.43246776 -1.         -0.45245495  0.22592251
#  -0.65270644] Estado: None Recompensa: -0.20874994307749262 Info: {'info': array(0.273875, dtype=float32)}
# Contador:  39
# Distancia previa : 0.274 m
# Distancia actual: 0.277 m
# Recompensa Distancia: -0.277
# Recompensa Costo: -0.5933031558990479
# Recompensa diferencia: -0.003
# Recompensa llegada: 0.2769489603898348
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.5963770937592554
# --------------------------------------------------------------------
# Acciones: [ 1.         -0.891636    1.         -1.          0.8734429   0.61246544
#   1.        ] Estado: None Recompensa: -0.5963770937592554 Info: {'info': array(0.27694896, dtype=float32)}
# Contador:  40
# Distancia previa : 0.277 m
# Distancia actual: 0.274 m
# Recompensa Distancia: -0.274
# Recompensa Costo: -0.42035675048828125
# Recompensa diferencia: 0.003
# Recompensa llegada: 0.273618579847197
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.4170263699456435
# --------------------------------------------------------------------
# Acciones: [-0.12206349  1.          1.          1.          0.39872542 -0.34335884
#   0.9548772 ] Estado: None Recompensa: -0.4170263699456435 Info: {'info': array(0.27361858, dtype=float32)}
# Contador:  41
# Distancia previa : 0.274 m
# Distancia actual: 0.277 m
# Recompensa Distancia: -0.277
# Recompensa Costo: -0.48980350494384767
# Recompensa diferencia: -0.004
# Recompensa llegada: 0.2772528050353077
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.49343773013195846
# --------------------------------------------------------------------
# Acciones: [-1.         -0.67593485 -0.16676012  0.9350575  -0.98668975  0.75196356
#  -1.        ] Estado: None Recompensa: -0.49343773013195846 Info: {'info': array(0.2772528, dtype=float32)}
# Contador:  42
# Distancia previa : 0.277 m
# Distancia actual: 0.274 m
# Recompensa Distancia: -0.274
# Recompensa Costo: -0.11797388792037965
# Recompensa diferencia: 0.003
# Recompensa llegada: 0.273888460914558
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.11460954379962995
# --------------------------------------------------------------------
# Acciones: [-0.37393197  0.18078953  0.851746   -0.04736701 -0.044516   -0.5138712
#   0.116055  ] Estado: None Recompensa: -0.11460954379962995 Info: {'info': array(0.27388844, dtype=float32)}
# Contador:  43
# Distancia previa : 0.274 m
# Distancia actual: 0.280 m
# Recompensa Distancia: -0.280
# Recompensa Costo: -0.5455565452575684
# Recompensa diferencia: -0.006
# Recompensa llegada: 0.2799185678160742
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.5515866521590846
# --------------------------------------------------------------------
# Acciones: [-0.20819056 -1.          1.         -0.7054451   1.         -0.9563312
#  -1.        ] Estado: None Recompensa: -0.5515866521590846 Info: {'info': array(0.27991855, dtype=float32)}
# Contador:  44
# Distancia previa : 0.280 m
# Distancia actual: 0.278 m
# Recompensa Distancia: -0.278
# Recompensa Costo: -0.27179603576660155
# Recompensa diferencia: 0.002
# Recompensa llegada: 0.27797586232797544
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.2698533302785028
# --------------------------------------------------------------------
# Acciones: [-0.8786691   0.53280944  0.6185838   1.          0.23326126 -0.45875588
#   0.12042265] Estado: None Recompensa: -0.2698533302785028 Info: {'info': array(0.27797586, dtype=float32)}
# Contador:  45
# Distancia previa : 0.278 m
# Distancia actual: 0.267 m
# Recompensa Distancia: -0.267
# Recompensa Costo: -0.22960302829742432
# Recompensa diferencia: 0.011
# Recompensa llegada: 0.2665824943470138
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.21820966031646272
# --------------------------------------------------------------------
# Acciones: [-0.04159275  1.          0.84573627 -0.3322106  -0.28750592  0.11433937
#   0.61068285] Estado: None Recompensa: -0.21820966031646272 Info: {'info': array(0.2665825, dtype=float32)}
# Contador:  46
# Distancia previa : 0.267 m
# Distancia actual: 0.259 m
# Recompensa Distancia: -0.259
# Recompensa Costo: -0.1367840647697449
# Recompensa diferencia: 0.007
# Recompensa llegada: 0.25926447190815405
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.12946604233088516
# --------------------------------------------------------------------
# Acciones: [ 0.46280426  0.38272148  0.41870373 -0.8858702   0.16484928 -0.06550078
#  -0.12503046] Estado: None Recompensa: -0.12946604233088516 Info: {'info': array(0.25926447, dtype=float32)}
# Contador:  47
# Distancia previa : 0.259 m
# Distancia actual: 0.245 m
# Recompensa Distancia: -0.245
# Recompensa Costo: -0.38088083267211914
# Recompensa diferencia: 0.014
# Recompensa llegada: 0.24496339721178503
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.36657975797575015
# --------------------------------------------------------------------
# Acciones: [ 0.17891653  0.58034647 -0.9876294  -1.         -0.30215046 -0.61097336
#   1.        ] Estado: None Recompensa: -0.36657975797575015 Info: {'info': array(0.24496341, dtype=float32)}
# Contador:  48
# Distancia previa : 0.245 m
# Distancia actual: 0.229 m
# Recompensa Distancia: -0.229
# Recompensa Costo: -0.2620642423629761
# Recompensa diferencia: 0.016
# Recompensa llegada: 0.22923284946290068
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.2463336946140917
# --------------------------------------------------------------------
# Acciones: [-0.04632778  0.93565524 -0.7335661  -0.4499426  -1.         -0.04828952
#   0.01208325] Estado: None Recompensa: -0.2463336946140917 Info: {'info': array(0.22923285, dtype=float32)}
# Contador:  49
# Distancia previa : 0.229 m
# Distancia actual: 0.225 m
# Recompensa Distancia: -0.225
# Recompensa Costo: -0.17236512899398804
# Recompensa diferencia: 0.005
# Recompensa llegada: 0.2246228800465135
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.16775515957760093
# --------------------------------------------------------------------
# Acciones: [-0.09100866 -0.28172636  0.15120636 -0.72901464 -1.          0.11755516
#   0.2604881 ] Estado: None Recompensa: -0.16775515957760093 Info: {'info': array(0.22462289, dtype=float32)}
# Contador:  50
# Distancia previa : 0.225 m
# Distancia actual: 0.216 m
# Recompensa Distancia: -0.216
# Recompensa Costo: -0.3373623609542847
# Recompensa diferencia: 0.009
# Recompensa llegada: 0.2156796065728796
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3284190874806508
# --------------------------------------------------------------------
# Acciones: [-1.         -0.04436442 -0.7743808  -0.27009326 -0.8104974   0.2052643
#   1.        ] Estado: None Recompensa: -0.3284190874806508 Info: {'info': array(0.21567962, dtype=float32)}
# Contador:  51
# Distancia previa : 0.216 m
# Distancia actual: 0.217 m
# Recompensa Distancia: -0.217
# Recompensa Costo: -0.502236270904541
# Recompensa diferencia: -0.002
# Recompensa llegada: 0.2173178698669205
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.503874534198582
# --------------------------------------------------------------------
# Acciones: [ 1.         -0.00892754  1.          0.7420685  -0.8654392   1.
#  -0.850078  ] Estado: None Recompensa: -0.503874534198582 Info: {'info': array(0.21731788, dtype=float32)}
# Contador:  52
# Distancia previa : 0.217 m
# Distancia actual: 0.221 m
# Recompensa Distancia: -0.221
# Recompensa Costo: -0.13013070821762085
# Recompensa diferencia: -0.004
# Recompensa llegada: 0.22123987045108268
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.13405270880178305
# --------------------------------------------------------------------
# Acciones: [ 0.16534433 -0.4210692   0.8482565  -0.18671906  0.5181747  -0.18339172
#  -0.2003205 ] Estado: None Recompensa: -0.13405270880178305 Info: {'info': array(0.22123988, dtype=float32)}
# Contador:  53
# Distancia previa : 0.221 m
# Distancia actual: 0.211 m
# Recompensa Distancia: -0.211
# Recompensa Costo: -0.38418776988983155
# Recompensa diferencia: 0.010
# Recompensa llegada: 0.21090398632735569
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.37385188576610456
# --------------------------------------------------------------------
# Acciones: [-0.89900947  0.09137037 -0.03769516 -1.         -1.         -0.15456498
#  -1.        ] Estado: None Recompensa: -0.37385188576610456 Info: {'info': array(0.21090399, dtype=float32)}
# Contador:  54
# Distancia previa : 0.211 m
# Distancia actual: 0.207 m
# Recompensa Distancia: -0.207
# Recompensa Costo: -0.45995559692382815
# Recompensa diferencia: 0.004
# Recompensa llegada: 0.20658851530828423
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.45564012590475667
# --------------------------------------------------------------------
# Acciones: [ 1.          0.12200917  0.6888199  -0.75436485 -1.          1.
#   0.73561585] Estado: None Recompensa: -0.45564012590475667 Info: {'info': array(0.20658852, dtype=float32)}
# Contador:  55
# Distancia previa : 0.207 m
# Distancia actual: 0.196 m
# Recompensa Distancia: -0.196
# Recompensa Costo: -0.27085094451904296
# Recompensa diferencia: 0.010
# Recompensa llegada: 0.19613439190349083
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.26039682111424955
# --------------------------------------------------------------------
# Acciones: [-0.25155663  1.         -0.55348355  0.17219216  0.5159666  -0.20739615
#   1.        ] Estado: None Recompensa: -0.26039682111424955 Info: {'info': array(0.19613439, dtype=float32)}
# Contador:  56
# Distancia previa : 0.196 m
# Distancia actual: 0.187 m
# Recompensa Distancia: -0.187
# Recompensa Costo: -0.29568822383880616
# Recompensa diferencia: 0.009
# Recompensa llegada: 0.18746568987953804
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.28701952181485335
# --------------------------------------------------------------------
# Acciones: [-0.43328866  1.          0.17644867 -0.82975066  0.9372747  -0.37484866
#  -0.17472155] Estado: None Recompensa: -0.28701952181485335 Info: {'info': array(0.18746567, dtype=float32)}
# Contador:  57
# Distancia previa : 0.187 m
# Distancia actual: 0.193 m
# Recompensa Distancia: -0.193
# Recompensa Costo: -0.3147845983505249
# Recompensa diferencia: -0.005
# Recompensa llegada: 0.1928960134531116
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3202149219240985
# --------------------------------------------------------------------
# Acciones: [ 1.         -0.03821067 -0.18773462  0.81760716  1.         -0.66282487
#   0.05764771] Estado: None Recompensa: -0.3202149219240985 Info: {'info': array(0.19289602, dtype=float32)}
# Contador:  58
# Distancia previa : 0.193 m
# Distancia actual: 0.188 m
# Recompensa Distancia: -0.188
# Recompensa Costo: -0.33057100772857667
# Recompensa diferencia: 0.005
# Recompensa llegada: 0.18827319098177234
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.32594818525723745
# --------------------------------------------------------------------
# Acciones: [-1.         -0.4021859  -0.57317656 -0.7070904  -0.6073102  -0.9527274
#   0.19731449] Estado: None Recompensa: -0.32594818525723745 Info: {'info': array(0.18827319, dtype=float32)}
# Contador:  59
# Distancia previa : 0.188 m
# Distancia actual: 0.180 m
# Recompensa Distancia: -0.180
# Recompensa Costo: -0.32783544063568115
# Recompensa diferencia: 0.008
# Recompensa llegada: 0.17988153443380311
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.31944378408771196
# --------------------------------------------------------------------
# Acciones: [-0.54945165  0.6008098  -0.7792252   1.          0.0901684  -0.01275349
#   1.        ] Estado: None Recompensa: -0.31944378408771196 Info: {'info': array(0.17988154, dtype=float32)}
# Contador:  60
# Distancia previa : 0.180 m
# Distancia actual: 0.170 m
# Recompensa Distancia: -0.170
# Recompensa Costo: -0.39605441093444826
# Recompensa diferencia: 0.010
# Recompensa llegada: 0.1699321607835696
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3861050372842148
# --------------------------------------------------------------------
# Acciones: [-0.7312286   0.5896523   0.08165365 -1.         -1.          0.26737916
#   1.        ] Estado: None Recompensa: -0.3861050372842148 Info: {'info': array(0.16993216, dtype=float32)}
# Contador:  61
# Distancia previa : 0.170 m
# Distancia actual: 0.157 m
# Recompensa Distancia: -0.157
# Recompensa Costo: -0.5215889930725098
# Recompensa diferencia: 0.013
# Recompensa llegada: 0.15657974687896997
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.5082365791679102
# --------------------------------------------------------------------
# Acciones: [-0.3604374   0.80426234 -1.         -0.66267437 -1.          1.
#   1.        ] Estado: None Recompensa: -0.5082365791679102 Info: {'info': array(0.15657975, dtype=float32)}
# Contador:  62
# Distancia previa : 0.157 m
# Distancia actual: 0.148 m
# Recompensa Distancia: -0.148
# Recompensa Costo: -0.4664055824279785
# Recompensa diferencia: 0.009
# Recompensa llegada: 0.14751824079933926
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.45734407634834773
# --------------------------------------------------------------------
# Acciones: [-0.91474384  1.         -1.          0.88313836  0.7824768   0.03487702
#   0.65869546] Estado: None Recompensa: -0.45734407634834773 Info: {'info': array(0.14751825, dtype=float32)}
# Contador:  63
# Distancia previa : 0.148 m
# Distancia actual: 0.140 m
# Recompensa Distancia: -0.140
# Recompensa Costo: -0.319607138633728
# Recompensa diferencia: 0.007
# Recompensa llegada: 0.14049788783739173
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.31258678567178044
# --------------------------------------------------------------------
# Acciones: [ 0.59012145  0.48608392 -0.55052274  0.3183853  -0.92672503  0.59015816
#  -1.        ] Estado: None Recompensa: -0.31258678567178044 Info: {'info': array(0.1404979, dtype=float32)}
# Contador:  64
# Distancia previa : 0.140 m
# Distancia actual: 0.143 m
# Recompensa Distancia: -0.143
# Recompensa Costo: -0.38883371353149415
# Recompensa diferencia: -0.002
# Recompensa llegada: 0.14294976738242404
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.39128559307652644
# --------------------------------------------------------------------
# Acciones: [ 0.01240876 -1.          1.          0.7381985   0.33184588  0.5414778
#  -0.96949786] Estado: None Recompensa: -0.39128559307652644 Info: {'info': array(0.14294979, dtype=float32)}
# Contador:  65
# Distancia previa : 0.143 m
# Distancia actual: 0.145 m
# Recompensa Distancia: -0.145
# Recompensa Costo: -0.2292374610900879
# Recompensa diferencia: -0.002
# Recompensa llegada: 0.14497409976402845
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.23126179347169226
# --------------------------------------------------------------------
# Acciones: [-0.21443643 -0.7747832  -0.437332   -0.6713959   1.          0.02713464
#  -0.05774779] Estado: None Recompensa: -0.23126179347169226 Info: {'info': array(0.1449741, dtype=float32)}
# Contador:  66
# Distancia previa : 0.145 m
# Distancia actual: 0.152 m
# Recompensa Distancia: -0.152
# Recompensa Costo: -0.4751675605773926
# Recompensa diferencia: -0.007
# Recompensa llegada: 0.15241776170954582
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.48261122252291
# --------------------------------------------------------------------
# Acciones: [ 1.         -1.          1.          1.          0.24743655  0.08171667
#  -0.8269058 ] Estado: None Recompensa: -0.48261122252291 Info: {'info': array(0.15241776, dtype=float32)}
# Contador:  67
# Distancia previa : 0.152 m
# Distancia actual: 0.159 m
# Recompensa Distancia: -0.159
# Recompensa Costo: -0.5592070579528808
# Recompensa diferencia: -0.007
# Recompensa llegada: 0.15917724524076196
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.565966541484097
# --------------------------------------------------------------------
# Acciones: [ 1.         -1.         -1.         -0.39108628  1.         -0.8232419
#   0.8725794 ] Estado: None Recompensa: -0.565966541484097 Info: {'info': array(0.15917724, dtype=float32)}
# Contador:  68
# Distancia previa : 0.159 m
# Distancia actual: 0.166 m
# Recompensa Distancia: -0.166
# Recompensa Costo: -0.46010742187500003
# Recompensa diferencia: -0.007
# Recompensa llegada: 0.1663025417448224
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.46723271837906044
# --------------------------------------------------------------------
# Acciones: [-0.9257507  -1.          0.8281207   0.21083076 -0.11758608 -1.
#  -1.        ] Estado: None Recompensa: -0.46723271837906044 Info: {'info': array(0.16630255, dtype=float32)}
# Contador:  69
# Distancia previa : 0.166 m
# Distancia actual: 0.178 m
# Recompensa Distancia: -0.178
# Recompensa Costo: -0.41276226043701175
# Recompensa diferencia: -0.012
# Recompensa llegada: 0.17806104165359526
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.4245207603457847
# --------------------------------------------------------------------
# Acciones: [ 0.6494206  -0.880397    1.         -0.01909774  0.89287055 -1.
#   0.36495748] Estado: None Recompensa: -0.4245207603457847 Info: {'info': array(0.17806104, dtype=float32)}
# Contador:  70
# Distancia previa : 0.178 m
# Distancia actual: 0.178 m
# Recompensa Distancia: -0.178
# Recompensa Costo: -0.38455982208251954
# Recompensa diferencia: 0.000
# Recompensa llegada: 0.17762055588672707
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3841193363156513
# --------------------------------------------------------------------
# Acciones: [ 1.          0.92956114  0.2848415  -0.4853801  -0.11757193 -1.
#   0.80682254] Estado: None Recompensa: -0.3841193363156513 Info: {'info': array(0.17762056, dtype=float32)}
# Contador:  71
# Distancia previa : 0.178 m
# Distancia actual: 0.189 m
# Recompensa Distancia: -0.189
# Recompensa Costo: -0.4257565975189209
# Recompensa diferencia: -0.012
# Recompensa llegada: 0.189234813155666
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.43737085478785986
# --------------------------------------------------------------------
# Acciones: [ 1.         -0.29403278  0.9617673   1.          0.6597799  -0.8687068
#   0.23696719] Estado: None Recompensa: -0.43737085478785986 Info: {'info': array(0.18923482, dtype=float32)}
# Contador:  72
# Distancia previa : 0.189 m
# Distancia actual: 0.191 m
# Recompensa Distancia: -0.191
# Recompensa Costo: -0.47803959846496585
# Recompensa diferencia: -0.001
# Recompensa llegada: 0.19067540412141784
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.4794801894307177
# --------------------------------------------------------------------
# Acciones: [-0.8863138  -0.6666914   1.         -0.6212143   0.85615027  1.
#  -0.65686035] Estado: None Recompensa: -0.4794801894307177 Info: {'info': array(0.19067541, dtype=float32)}
# Contador:  73
# Distancia previa : 0.191 m
# Distancia actual: 0.194 m
# Recompensa Distancia: -0.194
# Recompensa Costo: -0.3137663364410401
# Recompensa diferencia: -0.003
# Recompensa llegada: 0.19413242992432572
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3172233622439479
# --------------------------------------------------------------------
# Acciones: [ 0.206103   -0.01377197  0.8276302   0.05278662 -1.         -0.94269824
#   0.72010916] Estado: None Recompensa: -0.3172233622439479 Info: {'info': array(0.19413243, dtype=float32)}
# Contador:  74
# Distancia previa : 0.194 m
# Distancia actual: 0.184 m
# Recompensa Distancia: -0.184
# Recompensa Costo: -0.1680910587310791
# Recompensa diferencia: 0.010
# Recompensa llegada: 0.1844279187054861
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.1583865475122395
# --------------------------------------------------------------------
# Acciones: [-0.29789743  0.31534302 -0.3331363   0.4484354  -1.          0.4196665
#  -0.06732362] Estado: None Recompensa: -0.1583865475122395 Info: {'info': array(0.18442792, dtype=float32)}
# Contador:  75
# Distancia previa : 0.184 m
# Distancia actual: 0.174 m
# Recompensa Distancia: -0.174
# Recompensa Costo: -0.4238583564758301
# Recompensa diferencia: 0.010
# Recompensa llegada: 0.17418546752692926
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.41361590529727327
# --------------------------------------------------------------------
# Acciones: [ 0.20202745  1.         -0.2656362   1.         -1.          0.35665938
#   1.        ] Estado: None Recompensa: -0.41361590529727327 Info: {'info': array(0.17418547, dtype=float32)}
# Contador:  76
# Distancia previa : 0.174 m
# Distancia actual: 0.174 m
# Recompensa Distancia: -0.174
# Recompensa Costo: -0.3645639419555664
# Recompensa diferencia: 0.001
# Recompensa llegada: 0.17360404284303999
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3639825172716772
# --------------------------------------------------------------------
# Acciones: [ 0.4801322   0.5263726  -0.00573152  1.          1.          0.37149882
#  -1.        ] Estado: None Recompensa: -0.3639825172716772 Info: {'info': array(0.17360404, dtype=float32)}
# Contador:  77
# Distancia previa : 0.174 m
# Distancia actual: 0.184 m
# Recompensa Distancia: -0.184
# Recompensa Costo: -0.32294013500213625
# Recompensa diferencia: -0.010
# Recompensa llegada: 0.18354804902985183
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3328841411889482
# --------------------------------------------------------------------
# Acciones: [ 0.41237304 -1.          0.31314424  1.          0.5318019  -0.50011456
#   0.6544942 ] Estado: None Recompensa: -0.3328841411889482 Info: {'info': array(0.18354805, dtype=float32)}
# Contador:  78
# Distancia previa : 0.184 m
# Distancia actual: 0.182 m
# Recompensa Distancia: -0.182
# Recompensa Costo: -0.32497422695159917
# Recompensa diferencia: 0.002
# Recompensa llegada: 0.1816550024727621
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3230811803945094
# --------------------------------------------------------------------
# Acciones: [ 0.16405694 -0.43112412 -1.         -0.18730274  1.         -0.0433246
#  -1.        ] Estado: None Recompensa: -0.3230811803945094 Info: {'info': array(0.181655, dtype=float32)}
# Contador:  79
# Distancia previa : 0.182 m
# Distancia actual: 0.179 m
# Recompensa Distancia: -0.179
# Recompensa Costo: -0.3734721660614014
# Recompensa diferencia: 0.003
# Recompensa llegada: 0.17889822531737284
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3707153889060121
# --------------------------------------------------------------------
# Acciones: [-1.          0.38722074  0.7411149  -0.38150793 -0.18594958 -0.924881
#   1.        ] Estado: None Recompensa: -0.3707153889060121 Info: {'info': array(0.17889823, dtype=float32)}
# Contador:  80
# Distancia previa : 0.179 m
# Distancia actual: 0.174 m
# Recompensa Distancia: -0.174
# Recompensa Costo: -0.25922589302062987
# Recompensa diferencia: 0.005
# Recompensa llegada: 0.17382759249651536
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.2541552601997724
# --------------------------------------------------------------------
# Acciones: [-0.55687654 -0.27350402 -0.7218122   0.50928783  0.6532431   0.01514266
#   1.        ] Estado: None Recompensa: -0.2541552601997724 Info: {'info': array(0.17382759, dtype=float32)}
# Contador:  81
# Distancia previa : 0.174 m
# Distancia actual: 0.181 m
# Recompensa Distancia: -0.181
# Recompensa Costo: -0.34380292892456055
# Recompensa diferencia: -0.007
# Recompensa llegada: 0.18079222130235412
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3507675577303992
# --------------------------------------------------------------------
# Acciones: [ 0.07610708 -1.          1.         -0.32132244 -1.         -0.38724092
#  -0.42312366] Estado: None Recompensa: -0.3507675577303992 Info: {'info': array(0.18079223, dtype=float32)}
# Contador:  82
# Distancia previa : 0.181 m
# Distancia actual: 0.168 m
# Recompensa Distancia: -0.168
# Recompensa Costo: -0.5004334926605225
# Recompensa diferencia: 0.013
# Recompensa llegada: 0.16816269022667107
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.4878039615848395
# --------------------------------------------------------------------
# Acciones: [-1.          0.6590025  -0.8969762  -1.         -1.         -0.87411803
#   0.03744502] Estado: None Recompensa: -0.4878039615848395 Info: {'info': array(0.16816266, dtype=float32)}
# Contador:  83
# Distancia previa : 0.168 m
# Distancia actual: 0.162 m
# Recompensa Distancia: -0.162
# Recompensa Costo: -0.20784022808074953
# Recompensa diferencia: 0.007
# Recompensa llegada: 0.16162944570678914
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.20130698356086765
# --------------------------------------------------------------------
# Acciones: [-0.1559246   1.          0.11864914 -0.48930895 -0.88393974 -0.08982192
#   0.1056942 ] Estado: None Recompensa: -0.20130698356086765 Info: {'info': array(0.16162945, dtype=float32)}
# Contador:  84
# Distancia previa : 0.162 m
# Distancia actual: 0.159 m
# Recompensa Distancia: -0.159
# Recompensa Costo: -0.09353567957878113
# Recompensa diferencia: 0.003
# Recompensa llegada: 0.1587568643384857
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.09066309821047772
# --------------------------------------------------------------------
# Acciones: [ 0.26154217  0.43191782  0.03223388 -0.08356042 -0.00766338  0.41058964
#  -0.70974326] Estado: None Recompensa: -0.09066309821047772 Info: {'info': array(0.15875687, dtype=float32)}
# Contador:  85
# Distancia previa : 0.159 m
# Distancia actual: 0.162 m
# Recompensa Distancia: -0.162
# Recompensa Costo: -0.27217884063720704
# Recompensa diferencia: -0.003
# Recompensa llegada: 0.16187040646445527
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.2752923827631766
# --------------------------------------------------------------------
# Acciones: [-0.52116656  0.07074302  1.          0.57115346  0.96468633 -0.2589414
#   0.34825653] Estado: None Recompensa: -0.2752923827631766 Info: {'info': array(0.1618704, dtype=float32)}
# Contador:  86
# Distancia previa : 0.162 m
# Distancia actual: 0.149 m
# Recompensa Distancia: -0.149
# Recompensa Costo: -0.3495286703109741
# Recompensa diferencia: 0.013
# Recompensa llegada: 0.14854085138323095
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.33619911522974977
# --------------------------------------------------------------------
# Acciones: [-0.31717426  0.50230575 -1.          1.         -0.9297584   0.28307593
#  -0.4447397 ] Estado: None Recompensa: -0.33619911522974977 Info: {'info': array(0.14854085, dtype=float32)}
# Contador:  87
# Distancia previa : 0.149 m
# Distancia actual: 0.142 m
# Recompensa Distancia: -0.142
# Recompensa Costo: -0.3371851682662964
# Recompensa diferencia: 0.007
# Recompensa llegada: 0.14174594314737934
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3303902600304448
# --------------------------------------------------------------------
# Acciones: [-1.          0.107963    0.43086204  1.         -0.23186597  0.3475513
#  -1.        ] Estado: None Recompensa: -0.3303902600304448 Info: {'info': array(0.14174594, dtype=float32)}
# Contador:  88
# Distancia previa : 0.142 m
# Distancia actual: 0.138 m
# Recompensa Distancia: -0.138
# Recompensa Costo: -0.12082586288452149
# Recompensa diferencia: 0.004
# Recompensa llegada: 0.1381004155228364
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.11718033525997854
# --------------------------------------------------------------------
# Acciones: [-0.154946    0.11833446 -0.14163123  0.12833804  0.21348287  0.29688776
#  -1.        ] Estado: None Recompensa: -0.11718033525997854 Info: {'info': array(0.13810042, dtype=float32)}
# Contador:  89
# Distancia previa : 0.138 m
# Distancia actual: 0.134 m
# Recompensa Distancia: -0.134
# Recompensa Costo: -0.2706416130065918
# Recompensa diferencia: 0.004
# Recompensa llegada: 0.13382437304699588
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.26636557053075127
# --------------------------------------------------------------------
# Acciones: [-0.79395187 -0.58357036 -0.16052398  0.03828938  0.4458435   0.713787
#  -1.        ] Estado: None Recompensa: -0.26636557053075127 Info: {'info': array(0.13382438, dtype=float32)}
# Contador:  90
# Distancia previa : 0.134 m
# Distancia actual: 0.131 m
# Recompensa Distancia: -0.131
# Recompensa Costo: -0.2924716711044312
# Recompensa diferencia: 0.002
# Recompensa llegada: 0.13136541206701202
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.2900127101244473
# --------------------------------------------------------------------
# Acciones: [ 0.786342    0.1517145  -1.          0.28872818  0.4345359  -0.10573673
#   1.        ] Estado: None Recompensa: -0.2900127101244473 Info: {'info': array(0.13136542, dtype=float32)}
# Contador:  91
# Distancia previa : 0.131 m
# Distancia actual: 0.124 m
# Recompensa Distancia: -0.124
# Recompensa Costo: -0.35486555099487305
# Recompensa diferencia: 0.008
# Recompensa llegada: 0.12365341740520472
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.34715355633306577
# --------------------------------------------------------------------
# Acciones: [ 0.01082249  0.00726818 -0.86328506  0.8250147   1.          1.
#  -0.3501075 ] Estado: None Recompensa: -0.34715355633306577 Info: {'info': array(0.12365343, dtype=float32)}
# Contador:  92
# Distancia previa : 0.124 m
# Distancia actual: 0.128 m
# Recompensa Distancia: -0.128
# Recompensa Costo: -0.49457893371582035
# Recompensa diferencia: -0.004
# Recompensa llegada: 0.1278532976934795
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.4987788140040951
# --------------------------------------------------------------------
# Acciones: [ 1.          0.7259991   0.34142354  1.          0.5496766  -1.
#  -1.        ] Estado: None Recompensa: -0.4987788140040951 Info: {'info': array(0.1278533, dtype=float32)}
# Contador:  93
# Distancia previa : 0.128 m
# Distancia actual: 0.122 m
# Recompensa Distancia: -0.122
# Recompensa Costo: -0.31431586742401124
# Recompensa diferencia: 0.006
# Recompensa llegada: 0.12178484947286172
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3082474192033935
# --------------------------------------------------------------------
# Acciones: [-0.20926428  0.9974656  -0.6058017  -0.8198016   0.01983299  0.2548836
#  -1.        ] Estado: None Recompensa: -0.3082474192033935 Info: {'info': array(0.12178485, dtype=float32)}
# Contador:  94
# Distancia previa : 0.122 m
# Distancia actual: 0.131 m
# Recompensa Distancia: -0.131
# Recompensa Costo: -0.5612635135650635
# Recompensa diferencia: -0.009
# Recompensa llegada: 0.1307312597347758
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.5702099238269777
# --------------------------------------------------------------------
# Acciones: [ 1.          1.          1.          1.          0.63078886 -1.
#   0.46340123] Estado: None Recompensa: -0.5702099238269777 Info: {'info': array(0.13073125, dtype=float32)}
# Contador:  95
# Distancia previa : 0.131 m
# Distancia actual: 0.130 m
# Recompensa Distancia: -0.130
# Recompensa Costo: -0.2891913414001465
# Recompensa diferencia: 0.001
# Recompensa llegada: 0.13015502979273194
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.2886151114581026
# --------------------------------------------------------------------
# Acciones: [-1.         -0.12371624  0.17084962 -0.5523343  -0.2646792  -0.68723345
#  -1.        ] Estado: None Recompensa: -0.2886151114581026 Info: {'info': array(0.13015503, dtype=float32)}
# Contador:  96
# Distancia previa : 0.130 m
# Distancia actual: 0.134 m
# Recompensa Distancia: -0.134
# Recompensa Costo: -0.18163208961486818
# Recompensa diferencia: -0.004
# Recompensa llegada: 0.13429475930146842
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.18577181912360466
# --------------------------------------------------------------------
# Acciones: [ 1.         -0.09421273  0.34737974 -0.07763853 -0.77120656  0.1229964
#   0.2661891 ] Estado: None Recompensa: -0.18577181912360466 Info: {'info': array(0.13429476, dtype=float32)}
# Contador:  97
# Distancia previa : 0.134 m
# Distancia actual: 0.132 m
# Recompensa Distancia: -0.132
# Recompensa Costo: -0.2863814115524292
# Recompensa diferencia: 0.002
# Recompensa llegada: 0.13181537158004714
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.2839020238310079
# --------------------------------------------------------------------
# Acciones: [-0.24962282 -0.6624268   0.6064702   1.         -0.03342311  0.4473828
#   0.89085275] Estado: None Recompensa: -0.2839020238310079 Info: {'info': array(0.1318154, dtype=float32)}
# Contador:  98
# Distancia previa : 0.132 m
# Distancia actual: 0.130 m
# Recompensa Distancia: -0.130
# Recompensa Costo: -0.10818310976028443
# Recompensa diferencia: 0.002
# Recompensa llegada: 0.1297191351509717
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.10608687333120898
# --------------------------------------------------------------------
# Acciones: [-0.3736595   0.27485085  0.48903558  0.11722645 -0.43924454  0.20951764
#   0.6139507 ] Estado: None Recompensa: -0.10608687333120898 Info: {'info': array(0.12971914, dtype=float32)}
# Contador:  99
# Distancia previa : 0.130 m
# Distancia actual: 0.133 m
# Recompensa Distancia: -0.133
# Recompensa Costo: -0.25342769622802735
# Recompensa diferencia: -0.004
# Recompensa llegada: 0.13326038694467215
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.25696894802172787
# --------------------------------------------------------------------
# Acciones: [ 0.04810675 -0.2742411   0.6288708   0.13859096 -1.         -1.
#  -0.20510612] Estado: None Recompensa: -0.25696894802172787 Info: {'info': array(0.13326038, dtype=float32)}
# Contador:  100
# Distancia previa : 0.133 m
# Distancia actual: 0.145 m
# Recompensa Distancia: -0.145
# Recompensa Costo: -0.4340578556060791
# Recompensa diferencia: -0.011
# Recompensa llegada: 0.14473187968604553
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.4455293483474525
# --------------------------------------------------------------------
# Acciones: [ 1.          1.          1.          0.8153503   0.5269549  -0.6308059
#   0.01357807] Estado: None Recompensa: -0.4455293483474525 Info: {'info': array(0.14473188, dtype=float32)}

# %%
import gymnasium   #
import CoppeliaSim_Gym   # Entorno personalizado
import stable_baselines3   # Biblioteca RL
from stable_baselines3 import A2C, PPO
from matplotlib import pyplot as plt 
import pandas as pd
import numpy as np

# Inicializar el entorno
ENV_NAME = "CoppeliaSim_Gym/GymCoppManR-v0"
env = gymnasium.make(ENV_NAME)
model = A2C.load("modeloA2C", env=env)
model.policy
val = []
X_ = []
Y_ = []
all_episode_rewards = []
num_episodes = 25
for i in range(num_episodes):
    episode_rewards = []
    done = False
    obs, info = env.reset()
    while (1):
        # states solo son útiles cuando se usan políticas LSTM
        action, states = model.predict(obs, deterministic=False)
        # here, action, rewards and dones are arrays
        # because we are using vectorized env
        obs, reward, done, tru, info = env.step(action)
        episode_rewards.append(reward)
        val += [reward]
        X_.append(num_episodes)
        Y_.append(np.array(val).mean())
        
    all_episode_rewards.append(sum(episode_rewards))
plt.plot(X_, Y_)
plt.title('Acumulated reward')
plt.xlabel('Episodes')
plt.ylabel('Reward')
plt.show()
mean_episode_reward = np.mean(all_episode_rewards)
print("Mean reward:", mean_episode_reward, "Num episodes:", num_episodes)
env.close()
# Out:
# Conectado al servidor API remoto
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Contador:  1
# Distancia previa : 0.467 m
# Distancia actual: 0.471 m
# Recompensa Distancia: -0.471
# Recompensa Costo: -0.31458296775817873
# Recompensa diferencia: -0.004
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.7903706954271156
# --------------------------------------------------------------------
# Contador:  2
# Distancia previa : 0.471 m
# Distancia actual: 0.467 m
# Recompensa Distancia: -0.467
# Recompensa Costo: -0.42701587677001956
# Recompensa diferencia: 0.005
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.8889158992157562
# --------------------------------------------------------------------
# Contador:  3
# Distancia previa : 0.467 m
# Distancia actual: 0.481 m
# Recompensa Distancia: -0.481
# Recompensa Costo: -0.47004384994506837
# Recompensa diferencia: -0.014
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.9652140542546548
# --------------------------------------------------------------------
# Contador:  4
# Distancia previa : 0.481 m
# Distancia actual: 0.486 m
# Recompensa Distancia: -0.486
# Recompensa Costo: -0.3293951511383057
# Recompensa diferencia: -0.005
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.8205119105840815
# --------------------------------------------------------------------
# Contador:  5
# Distancia previa : 0.486 m
# Distancia actual: 0.483 m
# Recompensa Distancia: -0.483
# Recompensa Costo: -0.19563034772872925
# Recompensa diferencia: 0.003
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.6752312807446761
# --------------------------------------------------------------------
# Contador:  6
# Distancia previa : 0.483 m
# Distancia actual: 0.485 m
# Recompensa Distancia: -0.485
# Recompensa Costo: -0.3209702014923096
# Recompensa diferencia: -0.002
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.8074466633347324
# --------------------------------------------------------------------
# Contador:  7
# Distancia previa : 0.485 m
# Distancia actual: 0.480 m
# Recompensa Distancia: -0.480
# Recompensa Costo: -0.4023342609405518
# Recompensa diferencia: 0.005
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.8778177873235278
# --------------------------------------------------------------------
# Contador:  8
# Distancia previa : 0.480 m
# Distancia actual: 0.486 m
# Recompensa Distancia: -0.486
# Recompensa Costo: -0.42527399063110355
# Recompensa diferencia: -0.006
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.9176886890396422
# --------------------------------------------------------------------
# Contador:  9
# Distancia previa : 0.486 m
# Distancia actual: 0.477 m
# Recompensa Distancia: -0.477
# Recompensa Costo: -0.45062046051025395
# Recompensa diferencia: 0.009
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.9180411861892476
# --------------------------------------------------------------------
# Contador:  10
# Distancia previa : 0.477 m
# Distancia actual: 0.474 m
# Recompensa Distancia: -0.474
# Recompensa Costo: -0.41094245910644533
# Recompensa diferencia: 0.002
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.8828637276155101
# --------------------------------------------------------------------
# Contador:  11
# Distancia previa : 0.474 m
# Distancia actual: 0.482 m
# Recompensa Distancia: -0.482
# Recompensa Costo: -0.21847887039184571
# Recompensa diferencia: -0.007
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.7075291575256212
# --------------------------------------------------------------------
# Contador:  12
# Distancia previa : 0.482 m
# Distancia actual: 0.478 m
# Recompensa Distancia: -0.478
# Recompensa Costo: -0.3640528202056885
# Recompensa diferencia: 0.004
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.8384859358490557
# --------------------------------------------------------------------
# Contador:  13
# Distancia previa : 0.478 m
# Distancia actual: 0.471 m
# Recompensa Distancia: -0.471
# Recompensa Costo: -0.40178914070129396
# Recompensa diferencia: 0.007
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.866601345913351
# --------------------------------------------------------------------
# Contador:  14
# Distancia previa : 0.471 m
# Distancia actual: 0.467 m
# Recompensa Distancia: -0.467
# Recompensa Costo: -0.41283659934997563
# Recompensa diferencia: 0.005
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.8749805377614346
# --------------------------------------------------------------------
# Contador:  15
# Distancia previa : 0.467 m
# Distancia actual: 0.459 m
# Recompensa Distancia: -0.459
# Recompensa Costo: -0.20925905704498293
# Recompensa diferencia: 0.008
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.6605553726906193
# --------------------------------------------------------------------
# Contador:  16
# Distancia previa : 0.459 m
# Distancia actual: 0.458 m
# Recompensa Distancia: -0.458
# Recompensa Costo: -0.3415966033935547
# Recompensa diferencia: 0.001
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.7988547508981511
# --------------------------------------------------------------------
# Contador:  17
# Distancia previa : 0.458 m
# Distancia actual: 0.458 m
# Recompensa Distancia: -0.458
# Recompensa Costo: -0.13343091011047364
# Recompensa diferencia: -0.000
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.5920018725759573
# --------------------------------------------------------------------
# Contador:  18
# Distancia previa : 0.458 m
# Distancia actual: 0.470 m
# Recompensa Distancia: -0.470
# Recompensa Costo: -0.40900502204895023
# Recompensa diferencia: -0.012
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.8905022971970399
# --------------------------------------------------------------------
# Contador:  19
# Distancia previa : 0.470 m
# Distancia actual: 0.481 m
# Recompensa Distancia: -0.481
# Recompensa Costo: -0.3997992038726807
# Recompensa diferencia: -0.011
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.8913135243085656
# --------------------------------------------------------------------
# Contador:  20
# Distancia previa : 0.481 m
# Distancia actual: 0.486 m
# Recompensa Distancia: -0.486
# Recompensa Costo: -0.1446851968765259
# Recompensa diferencia: -0.006
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.6366035837734147
# --------------------------------------------------------------------
# Contador:  21
# Distancia previa : 0.486 m
# Distancia actual: 0.465 m
# Recompensa Distancia: -0.465
# Recompensa Costo: -0.3342113018035889
# Recompensa diferencia: 0.022
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.7771492082483981
# --------------------------------------------------------------------
# Contador:  22
# Distancia previa : 0.465 m
# Distancia actual: 0.446 m
# Recompensa Distancia: -0.446
# Recompensa Costo: -0.4440354824066162
# Recompensa diferencia: 0.019
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.870638293216484
# --------------------------------------------------------------------
# Contador:  23
# Distancia previa : 0.446 m
# Distancia actual: 0.447 m
# Recompensa Distancia: -0.447
# Recompensa Costo: -0.2643324375152588
# Recompensa diferencia: -0.001
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.7126400946808966
# --------------------------------------------------------------------
# Contador:  24
# Distancia previa : 0.447 m
# Distancia actual: 0.429 m
# Recompensa Distancia: -0.429
# Recompensa Costo: -0.5190603256225587
# Recompensa diferencia: 0.017
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.9310292076223843
# --------------------------------------------------------------------
# Contador:  25
# Distancia previa : 0.429 m
# Distancia actual: 0.428 m
# Recompensa Distancia: -0.428
# Recompensa Costo: -0.34687418937683107
# Recompensa diferencia: 0.002
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.7726917468101566
# --------------------------------------------------------------------
# Contador:  26
# Distancia previa : 0.428 m
# Distancia actual: 0.410 m
# Recompensa Distancia: -0.410
# Recompensa Costo: -0.29470267295837405
# Recompensa diferencia: 0.017
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.6874027507426999
# --------------------------------------------------------------------
# Contador:  27
# Distancia previa : 0.410 m
# Distancia actual: 0.405 m
# Recompensa Distancia: -0.405
# Recompensa Costo: -0.1741954803466797
# Recompensa diferencia: 0.005
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.5744214406640801
# --------------------------------------------------------------------
# Contador:  28
# Distancia previa : 0.405 m
# Distancia actual: 0.402 m
# Recompensa Distancia: -0.402
# Recompensa Costo: -0.3649737358093262
# Recompensa diferencia: 0.003
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.764697039363762
# --------------------------------------------------------------------
# Contador:  29
# Distancia previa : 0.402 m
# Distancia actual: 0.414 m
# Recompensa Distancia: -0.414
# Recompensa Costo: -0.38384246826171875
# Recompensa diferencia: -0.012
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.8099038671743547
# --------------------------------------------------------------------
# Contador:  30
# Distancia previa : 0.414 m
# Distancia actual: 0.419 m
# Recompensa Distancia: -0.419
# Recompensa Costo: -0.19197328090667726
# Recompensa diferencia: -0.004
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.6149515415674973
# --------------------------------------------------------------------
# Contador:  31
# Distancia previa : 0.419 m
# Distancia actual: 0.413 m
# Recompensa Distancia: -0.413
# Recompensa Costo: -0.25613267421722413
# Recompensa diferencia: 0.005
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.6642543885186707
# --------------------------------------------------------------------
# Contador:  32
# Distancia previa : 0.413 m
# Distancia actual: 0.421 m
# Recompensa Distancia: -0.421
# Recompensa Costo: -0.28168063163757323
# Recompensa diferencia: -0.008
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.710320917987993
# --------------------------------------------------------------------
# Contador:  33
# Distancia previa : 0.421 m
# Distancia actual: 0.422 m
# Recompensa Distancia: -0.422
# Recompensa Costo: -0.3266769886016846
# Recompensa diferencia: -0.001
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.7505051286520205
# --------------------------------------------------------------------
# Contador:  34
# Distancia previa : 0.422 m
# Distancia actual: 0.411 m
# Recompensa Distancia: -0.411
# Recompensa Costo: -0.26386682987213134
# Recompensa diferencia: 0.011
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.6636693324838696
# --------------------------------------------------------------------
# Contador:  35
# Distancia previa : 0.411 m
# Distancia actual: 0.413 m
# Recompensa Distancia: -0.413
# Recompensa Costo: -0.31247470378875736
# Recompensa diferencia: -0.002
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.7279981462279442
# --------------------------------------------------------------------
# Contador:  36
# Distancia previa : 0.413 m
# Distancia actual: 0.392 m
# Recompensa Distancia: -0.392
# Recompensa Costo: -0.3512222528457642
# Recompensa diferencia: 0.021
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.7222290821873378
# --------------------------------------------------------------------
# Contador:  37
# Distancia previa : 0.392 m
# Distancia actual: 0.406 m
# Recompensa Distancia: -0.406
# Recompensa Costo: -0.4946167469024658
# Recompensa diferencia: -0.014
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.9143540624664903
# --------------------------------------------------------------------
# Contador:  38
# Distancia previa : 0.406 m
# Distancia actual: 0.410 m
# Recompensa Distancia: -0.410
# Recompensa Costo: -0.5770688056945801
# Recompensa diferencia: -0.004
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.9904594264670235
# --------------------------------------------------------------------
# Contador:  39
# Distancia previa : 0.410 m
# Distancia actual: 0.419 m
# Recompensa Distancia: -0.419
# Recompensa Costo: -0.37465426921844486
# Recompensa diferencia: -0.010
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.803820590346526
# --------------------------------------------------------------------
# Contador:  40
# Distancia previa : 0.419 m
# Distancia actual: 0.409 m
# Recompensa Distancia: -0.409
# Recompensa Costo: -0.5403035163879395
# Recompensa diferencia: 0.011
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.938178551405266
# --------------------------------------------------------------------
# Contador:  41
# Distancia previa : 0.409 m
# Distancia actual: 0.400 m
# Recompensa Distancia: -0.400
# Recompensa Costo: -0.2576101541519165
# Recompensa diferencia: 0.009
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.6482420847043424
# --------------------------------------------------------------------
# Contador:  42
# Distancia previa : 0.400 m
# Distancia actual: 0.387 m
# Recompensa Distancia: -0.387
# Recompensa Costo: -0.35878863334655764
# Recompensa diferencia: 0.012
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.7338484028592219
# --------------------------------------------------------------------
# Contador:  43
# Distancia previa : 0.387 m
# Distancia actual: 0.395 m
# Recompensa Distancia: -0.395
# Recompensa Costo: -0.28401682376861576
# Recompensa diferencia: -0.008
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.6865718068198475
# --------------------------------------------------------------------
# Contador:  44
# Distancia previa : 0.395 m
# Distancia actual: 0.403 m
# Recompensa Distancia: -0.403
# Recompensa Costo: -0.36971459388732913
# Recompensa diferencia: -0.008
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.7807276679394151
# --------------------------------------------------------------------
# Contador:  45
# Distancia previa : 0.403 m
# Distancia actual: 0.402 m
# Recompensa Distancia: -0.402
# Recompensa Costo: -0.2124819278717041
# Recompensa diferencia: 0.001
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.6144141489923494
# --------------------------------------------------------------------
# Contador:  46
# Distancia previa : 0.402 m
# Distancia actual: 0.403 m
# Recompensa Distancia: -0.403
# Recompensa Costo: -0.33508968353271484
# Recompensa diferencia: -0.001
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.7389283248889035
# --------------------------------------------------------------------
# Contador:  47
# Distancia previa : 0.403 m
# Distancia actual: 0.403 m
# Recompensa Distancia: -0.403
# Recompensa Costo: -0.2549891948699951
# Recompensa diferencia: 0.000
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.6578091984411767
# --------------------------------------------------------------------
# Contador:  48
# Distancia previa : 0.403 m
# Distancia actual: 0.401 m
# Recompensa Distancia: -0.401
# Recompensa Costo: -0.3029845714569092
# Recompensa diferencia: 0.002
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.7019246949045206
# --------------------------------------------------------------------
# Contador:  49
# Distancia previa : 0.401 m
# Distancia actual: 0.400 m
# Recompensa Distancia: -0.400
# Recompensa Costo: -0.3974380970001221
# Recompensa diferencia: 0.001
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.7967889940333663
# --------------------------------------------------------------------
# Contador:  50
# Distancia previa : 0.400 m
# Distancia actual: 0.403 m
# Recompensa Distancia: -0.403
# Recompensa Costo: -0.5093803405761719
# Recompensa diferencia: -0.003
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.9161093144192226
# --------------------------------------------------------------------
# Contador:  51
# Distancia previa : 0.403 m
# Distancia actual: 0.378 m
# Recompensa Distancia: -0.378
# Recompensa Costo: -0.4362353324890137
# Recompensa diferencia: 0.026
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.7883027785591017
# --------------------------------------------------------------------
# Contador:  52
# Distancia previa : 0.378 m
# Distancia actual: 0.375 m
# Recompensa Distancia: -0.375
# Recompensa Costo: -0.16191956996917725
# Recompensa diferencia: 0.003
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.534464167484234
# --------------------------------------------------------------------
# Contador:  53
# Distancia previa : 0.375 m
# Distancia actual: 0.368 m
# Recompensa Distancia: -0.368
# Recompensa Costo: -0.08171280026435852
# Recompensa diferencia: 0.007
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.4426295953796421
# --------------------------------------------------------------------
# Contador:  54
# Distancia previa : 0.368 m
# Distancia actual: 0.367 m
# Recompensa Distancia: -0.367
# Recompensa Costo: -0.33335380554199223
# Recompensa diferencia: 0.001
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.7000579481692956
# --------------------------------------------------------------------
# Contador:  55
# Distancia previa : 0.367 m
# Distancia actual: 0.366 m
# Recompensa Distancia: -0.366
# Recompensa Costo: -0.4923684597015381
# Recompensa diferencia: 0.001
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.857183572285443
# --------------------------------------------------------------------
# Contador:  56
# Distancia previa : 0.366 m
# Distancia actual: 0.371 m
# Recompensa Distancia: -0.371
# Recompensa Costo: -0.4092745304107666
# Recompensa diferencia: -0.005
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.7854941933224827
# --------------------------------------------------------------------
# Contador:  57
# Distancia previa : 0.371 m
# Distancia actual: 0.385 m
# Recompensa Distancia: -0.385
# Recompensa Costo: -0.517917251586914
# Recompensa diferencia: -0.014
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.916310757061336
# --------------------------------------------------------------------
# Contador:  58
# Distancia previa : 0.385 m
# Distancia actual: 0.380 m
# Recompensa Distancia: -0.380
# Recompensa Costo: -0.21554596424102784
# Recompensa diferencia: 0.005
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.5910917178322973
# --------------------------------------------------------------------
# Contador:  59
# Distancia previa : 0.380 m
# Distancia actual: 0.363 m
# Recompensa Distancia: -0.363
# Recompensa Costo: -0.14223061800003053
# Recompensa diferencia: 0.017
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.48821437732655437
# --------------------------------------------------------------------
# Contador:  60
# Distancia previa : 0.363 m
# Distancia actual: 0.355 m
# Recompensa Distancia: -0.355
# Recompensa Costo: -0.375900411605835
# Recompensa diferencia: 0.008
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.7227791563812866
# --------------------------------------------------------------------
# Contador:  61
# Distancia previa : 0.355 m
# Distancia actual: 0.356 m
# Recompensa Distancia: -0.356
# Recompensa Costo: -0.18700227737426758
# Recompensa diferencia: -0.001
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.5433320977952765
# --------------------------------------------------------------------
# Contador:  62
# Distancia previa : 0.356 m
# Distancia actual: 0.360 m
# Recompensa Distancia: -0.360
# Recompensa Costo: -0.38752408027648927
# Recompensa diferencia: -0.004
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.7514457604736898
# --------------------------------------------------------------------
# Contador:  63
# Distancia previa : 0.360 m
# Distancia actual: 0.351 m
# Recompensa Distancia: -0.351
# Recompensa Costo: -0.36905937194824223
# Recompensa diferencia: 0.008
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.7120980229699162
# --------------------------------------------------------------------
# Contador:  64
# Distancia previa : 0.351 m
# Distancia actual: 0.328 m
# Recompensa Distancia: -0.328
# Recompensa Costo: -0.3726295232772827
# Recompensa diferencia: 0.023
# Recompensa llegada: 0.3283456035700529
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3495622334185074
# --------------------------------------------------------------------
# Contador:  65
# Distancia previa : 0.328 m
# Distancia actual: 0.325 m
# Recompensa Distancia: -0.325
# Recompensa Costo: -0.27518553733825685
# Recompensa diferencia: 0.003
# Recompensa llegada: 0.32501137287433784
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.2718513066425418
# --------------------------------------------------------------------
# Contador:  66
# Distancia previa : 0.325 m
# Distancia actual: 0.314 m
# Recompensa Distancia: -0.314
# Recompensa Costo: -0.244453763961792
# Recompensa diferencia: 0.011
# Recompensa llegada: 0.31362098980655345
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.23306338089400763
# --------------------------------------------------------------------
# Contador:  67
# Distancia previa : 0.314 m
# Distancia actual: 0.296 m
# Recompensa Distancia: -0.296
# Recompensa Costo: -0.26495859622955326
# Recompensa diferencia: 0.018
# Recompensa llegada: 0.29571014285023894
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.24704774927323875
# --------------------------------------------------------------------
# Contador:  68
# Distancia previa : 0.296 m
# Distancia actual: 0.302 m
# Recompensa Distancia: -0.302
# Recompensa Costo: -0.49777936935424805
# Recompensa diferencia: -0.007
# Recompensa llegada: 0.3022300501158675
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.5042992766198766
# --------------------------------------------------------------------
# Contador:  69
# Distancia previa : 0.302 m
# Distancia actual: 0.299 m
# Recompensa Distancia: -0.299
# Recompensa Costo: -0.2623760223388672
# Recompensa diferencia: 0.003
# Recompensa llegada: 0.298748870790545
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.2588948430135447
# --------------------------------------------------------------------
# Contador:  70
# Distancia previa : 0.299 m
# Distancia actual: 0.302 m
# Recompensa Distancia: -0.302
# Recompensa Costo: -0.29858856201171874
# Recompensa diferencia: -0.003
# Recompensa llegada: 0.3016463468080723
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.30148603802924595
# --------------------------------------------------------------------
# Contador:  71
# Distancia previa : 0.302 m
# Distancia actual: 0.290 m
# Recompensa Distancia: -0.290
# Recompensa Costo: -0.2438736915588379
# Recompensa diferencia: 0.011
# Recompensa llegada: 0.2902638665358021
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.23249121128656774
# --------------------------------------------------------------------
# Contador:  72
# Distancia previa : 0.290 m
# Distancia actual: 0.295 m
# Recompensa Distancia: -0.295
# Recompensa Costo: -0.13990148305892944
# Recompensa diferencia: -0.004
# Recompensa llegada: 0.2945673211310953
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.14420493765422265
# --------------------------------------------------------------------
# Contador:  73
# Distancia previa : 0.295 m
# Distancia actual: 0.273 m
# Recompensa Distancia: -0.273
# Recompensa Costo: -0.49389352798461916
# Recompensa diferencia: 0.022
# Recompensa llegada: 0.2725850440700899
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.47191125092361375
# --------------------------------------------------------------------
# Contador:  74
# Distancia previa : 0.273 m
# Distancia actual: 0.264 m
# Recompensa Distancia: -0.264
# Recompensa Costo: -0.40261335372924806
# Recompensa diferencia: 0.009
# Recompensa llegada: 0.26389690894778
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.39392521860693824
# --------------------------------------------------------------------
# Contador:  75
# Distancia previa : 0.264 m
# Distancia actual: 0.277 m
# Recompensa Distancia: -0.277
# Recompensa Costo: -0.18926844596862794
# Recompensa diferencia: -0.014
# Recompensa llegada: 0.2774350313390292
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.20280656835987715
# --------------------------------------------------------------------
# Contador:  76
# Distancia previa : 0.277 m
# Distancia actual: 0.283 m
# Recompensa Distancia: -0.283
# Recompensa Costo: -0.35749220848083496
# Recompensa diferencia: -0.006
# Recompensa llegada: 0.28323609567350977
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3632932728153156
# --------------------------------------------------------------------
# Contador:  77
# Distancia previa : 0.283 m
# Distancia actual: 0.265 m
# Recompensa Distancia: -0.265
# Recompensa Costo: -0.6122289180755616
# Recompensa diferencia: 0.019
# Recompensa llegada: 0.2647308207285568
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.5937236431306085
# --------------------------------------------------------------------
# Contador:  78
# Distancia previa : 0.265 m
# Distancia actual: 0.254 m
# Recompensa Distancia: -0.254
# Recompensa Costo: -0.20988261699676514
# Recompensa diferencia: 0.010
# Recompensa llegada: 0.25449829264286233
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.19965008891107067
# --------------------------------------------------------------------
# Contador:  79
# Distancia previa : 0.254 m
# Distancia actual: 0.238 m
# Recompensa Distancia: -0.238
# Recompensa Costo: -0.30971608161926273
# Recompensa diferencia: 0.017
# Recompensa llegada: 0.23783658006228897
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.29305436903868937
# --------------------------------------------------------------------
# Contador:  80
# Distancia previa : 0.238 m
# Distancia actual: 0.229 m
# Recompensa Distancia: -0.229
# Recompensa Costo: -0.2764272689819336
# Recompensa diferencia: 0.009
# Recompensa llegada: 0.22866817089837185
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.26725885981801645
# --------------------------------------------------------------------
# Contador:  81
# Distancia previa : 0.229 m
# Distancia actual: 0.237 m
# Recompensa Distancia: -0.237
# Recompensa Costo: -0.3180593490600586
# Recompensa diferencia: -0.009
# Recompensa llegada: 0.23732452425307624
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.326715702414763
# --------------------------------------------------------------------
# Contador:  82
# Distancia previa : 0.237 m
# Distancia actual: 0.224 m
# Recompensa Distancia: -0.224
# Recompensa Costo: -0.33079483509063723
# Recompensa diferencia: 0.013
# Recompensa llegada: 0.22399801103703637
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.31746832187459745
# --------------------------------------------------------------------
# Contador:  83
# Distancia previa : 0.224 m
# Distancia actual: 0.208 m
# Recompensa Distancia: -0.208
# Recompensa Costo: -0.3390833854675293
# Recompensa diferencia: 0.016
# Recompensa llegada: 0.2080747601199965
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.32316013455048953
# --------------------------------------------------------------------
# Contador:  84
# Distancia previa : 0.208 m
# Distancia actual: 0.204 m
# Recompensa Distancia: -0.204
# Recompensa Costo: -0.24890387058258057
# Recompensa diferencia: 0.005
# Recompensa llegada: 0.20353800403828656
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.24436711450087065
# --------------------------------------------------------------------
# Contador:  85
# Distancia previa : 0.204 m
# Distancia actual: 0.213 m
# Recompensa Distancia: -0.213
# Recompensa Costo: -0.3694174766540528
# Recompensa diferencia: -0.009
# Recompensa llegada: 0.212793904528004
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3786733771437703
# --------------------------------------------------------------------
# Contador:  86
# Distancia previa : 0.213 m
# Distancia actual: 0.211 m
# Recompensa Distancia: -0.211
# Recompensa Costo: -0.4982772827148438
# Recompensa diferencia: 0.002
# Recompensa llegada: 0.21108868706625006
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.49657206525308983
# --------------------------------------------------------------------
# Contador:  87
# Distancia previa : 0.211 m
# Distancia actual: 0.200 m
# Recompensa Distancia: -0.200
# Recompensa Costo: -0.23177518844604494
# Recompensa diferencia: 0.011
# Recompensa llegada: 0.20033083114447994
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.22101733252427477
# --------------------------------------------------------------------
# Contador:  88
# Distancia previa : 0.200 m
# Distancia actual: 0.185 m
# Recompensa Distancia: -0.185
# Recompensa Costo: -0.30520632266998293
# Recompensa diferencia: 0.015
# Recompensa llegada: 0.18539995720249486
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.2902754487279979
# --------------------------------------------------------------------
# Contador:  89
# Distancia previa : 0.185 m
# Distancia actual: 0.196 m
# Recompensa Distancia: -0.196
# Recompensa Costo: -0.23209898471832277
# Recompensa diferencia: -0.011
# Recompensa llegada: 0.19628325745702532
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.24298228497285326
# --------------------------------------------------------------------
# Contador:  90
# Distancia previa : 0.196 m
# Distancia actual: 0.205 m
# Recompensa Distancia: -0.205
# Recompensa Costo: -0.35952596664428715
# Recompensa diferencia: -0.008
# Recompensa llegada: 0.20452809796900162
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3677708071562634
# --------------------------------------------------------------------
# Contador:  91
# Distancia previa : 0.205 m
# Distancia actual: 0.205 m
# Recompensa Distancia: -0.205
# Recompensa Costo: -0.3614928007125855
# Recompensa diferencia: -0.000
# Recompensa llegada: 0.20469949518598837
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3616641979295723
# --------------------------------------------------------------------
# Contador:  92
# Distancia previa : 0.205 m
# Distancia actual: 0.200 m
# Recompensa Distancia: -0.200
# Recompensa Costo: -0.3810487747192383
# Recompensa diferencia: 0.005
# Recompensa llegada: 0.20018676678240238
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.37653604631565235
# --------------------------------------------------------------------
# Contador:  93
# Distancia previa : 0.200 m
# Distancia actual: 0.215 m
# Recompensa Distancia: -0.215
# Recompensa Costo: -0.383334755897522
# Recompensa diferencia: -0.015
# Recompensa llegada: 0.21497875244323725
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3981267415583568
# --------------------------------------------------------------------
# Contador:  94
# Distancia previa : 0.215 m
# Distancia actual: 0.225 m
# Recompensa Distancia: -0.225
# Recompensa Costo: -0.30096254348754886
# Recompensa diferencia: -0.010
# Recompensa llegada: 0.22547354868605018
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3114573397303618
# --------------------------------------------------------------------
# Contador:  95
# Distancia previa : 0.225 m
# Distancia actual: 0.215 m
# Recompensa Distancia: -0.215
# Recompensa Costo: -0.3024225473403931
# Recompensa diferencia: 0.011
# Recompensa llegada: 0.21489921692958774
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.29184821558393065
# --------------------------------------------------------------------
# Contador:  96
# Distancia previa : 0.215 m
# Distancia actual: 0.214 m
# Recompensa Distancia: -0.214
# Recompensa Costo: -0.27485783100128175
# Recompensa diferencia: 0.001
# Recompensa llegada: 0.21364438249188034
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.27360299656357434
# --------------------------------------------------------------------
# Contador:  97
# Distancia previa : 0.214 m
# Distancia actual: 0.208 m
# Recompensa Distancia: -0.208
# Recompensa Costo: -0.37887096405029297
# Recompensa diferencia: 0.006
# Recompensa llegada: 0.20763956792969515
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3728661494881078
# --------------------------------------------------------------------
# Contador:  98
# Distancia previa : 0.208 m
# Distancia actual: 0.210 m
# Recompensa Distancia: -0.210
# Recompensa Costo: -0.3661493539810181
# Recompensa diferencia: -0.003
# Recompensa llegada: 0.21015171514363865
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.36866150119496155
# --------------------------------------------------------------------
# Contador:  99
# Distancia previa : 0.210 m
# Distancia actual: 0.205 m
# Recompensa Distancia: -0.205
# Recompensa Costo: -0.29299249649047854
# Recompensa diferencia: 0.005
# Recompensa llegada: 0.2054867678017459
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.2883275491485858
# --------------------------------------------------------------------
# Contador:  100
# Distancia previa : 0.205 m
# Distancia actual: 0.202 m
# Recompensa Distancia: -0.202
# Recompensa Costo: -0.22379627227783205
# Recompensa diferencia: 0.003
# Recompensa llegada: 0.2020280060550097
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.22033751053109585
# --------------------------------------------------------------------
# Contador:  101
# Distancia previa : 0.202 m
# Distancia actual: 0.213 m
# Recompensa Distancia: -0.213
# Recompensa Costo: -0.3689762592315674
# Recompensa diferencia: -0.011
# Recompensa llegada: 0.21298228284958484
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3799305360261426
# --------------------------------------------------------------------
# Contador:  102
# Distancia previa : 0.213 m
# Distancia actual: 0.199 m
# Recompensa Distancia: -0.199
# Recompensa Costo: -0.3859029769897461
# Recompensa diferencia: 0.014
# Recompensa llegada: 0.19851507657417145
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.37143577071433276
# --------------------------------------------------------------------
# Contador:  103
# Distancia previa : 0.199 m
# Distancia actual: 0.190 m
# Recompensa Distancia: -0.190
# Recompensa Costo: -0.34241929054260256
# Recompensa diferencia: 0.009
# Recompensa llegada: 0.1896620267803004
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.33356624074873154
# --------------------------------------------------------------------
# Contador:  104
# Distancia previa : 0.190 m
# Distancia actual: 0.175 m
# Recompensa Distancia: -0.175
# Recompensa Costo: -0.3224846839904785
# Recompensa diferencia: 0.015
# Recompensa llegada: 0.17507962899452686
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.30790228620470494
# --------------------------------------------------------------------
# Contador:  105
# Distancia previa : 0.175 m
# Distancia actual: 0.173 m
# Recompensa Distancia: -0.173
# Recompensa Costo: -0.22527847290039063
# Recompensa diferencia: 0.002
# Recompensa llegada: 0.17295143058391185
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.22315027448977562
# --------------------------------------------------------------------
# Contador:  106
# Distancia previa : 0.173 m
# Distancia actual: 0.159 m
# Recompensa Distancia: -0.159
# Recompensa Costo: -0.3002969741821289
# Recompensa diferencia: 0.014
# Recompensa llegada: 0.1586541413352747
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.2859996849334918
# --------------------------------------------------------------------
# Contador:  107
# Distancia previa : 0.159 m
# Distancia actual: 0.157 m
# Recompensa Distancia: -0.157
# Recompensa Costo: -0.33761320114135746
# Recompensa diferencia: 0.002
# Recompensa llegada: 0.15656128802608432
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.33552034783216705
# --------------------------------------------------------------------
# Contador:  108
# Distancia previa : 0.157 m
# Distancia actual: 0.153 m
# Recompensa Distancia: -0.153
# Recompensa Costo: -0.2610900402069092
# Recompensa diferencia: 0.004
# Recompensa llegada: 0.1529196400520173
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.25744839223284216
# --------------------------------------------------------------------
# Contador:  109
# Distancia previa : 0.153 m
# Distancia actual: 0.139 m
# Recompensa Distancia: -0.139
# Recompensa Costo: -0.5656218051910401
# Recompensa diferencia: 0.014
# Recompensa llegada: 0.13899418681194267
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.5516963519509654
# --------------------------------------------------------------------
# Contador:  110
# Distancia previa : 0.139 m
# Distancia actual: 0.128 m
# Recompensa Distancia: -0.128
# Recompensa Costo: -0.4015598773956299
# Recompensa diferencia: 0.011
# Recompensa llegada: 0.127830274201192
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.39039596478487926
# --------------------------------------------------------------------
# Contador:  111
# Distancia previa : 0.128 m
# Distancia actual: 0.114 m
# Recompensa Distancia: -0.114
# Recompensa Costo: -0.3656522274017334
# Recompensa diferencia: 0.013
# Recompensa llegada: 0.11436730562658326
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3521892588271247
# --------------------------------------------------------------------
# Contador:  112
# Distancia previa : 0.114 m
# Distancia actual: 0.096 m
# Recompensa Distancia: -0.096
# Recompensa Costo: -0.45155248641967777
# Recompensa diferencia: 0.019
# Recompensa llegada: 0.09582863507021018
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.43301381586330473
# --------------------------------------------------------------------
# Contador:  113
# Distancia previa : 0.096 m
# Distancia actual: 0.102 m
# Recompensa Distancia: -0.102
# Recompensa Costo: -0.40322203636169435
# Recompensa diferencia: -0.006
# Recompensa llegada: 0.10199098820561968
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.40938438949710376
# --------------------------------------------------------------------
# Contador:  114
# Distancia previa : 0.102 m
# Distancia actual: 0.093 m
# Recompensa Distancia: -0.093
# Recompensa Costo: -0.2184903144836426
# Recompensa diferencia: 0.009
# Recompensa llegada: 0.09259032829020451
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.20908965456822742
# --------------------------------------------------------------------
# Contador:  115
# Distancia previa : 0.093 m
# Distancia actual: 0.081 m
# Recompensa Distancia: -0.081
# Recompensa Costo: -0.49880094528198243
# Recompensa diferencia: 0.011
# Recompensa llegada: 0.08131652207694325
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.4875271390687212
# --------------------------------------------------------------------
# Contador:  116
# Distancia previa : 0.081 m
# Distancia actual: 0.083 m
# Recompensa Distancia: -0.083
# Recompensa Costo: -0.26084289550781253
# Recompensa diferencia: -0.002
# Recompensa llegada: 0.08329358545177923
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.26281995888264853
# --------------------------------------------------------------------
# Contador:  117
# Distancia previa : 0.083 m
# Distancia actual: 0.086 m
# Recompensa Distancia: -0.086
# Recompensa Costo: -0.353901743888855
# Recompensa diferencia: -0.003
# Recompensa llegada: 0.08602189500878264
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3566300534458584
# --------------------------------------------------------------------
# Contador:  118
# Distancia previa : 0.086 m
# Distancia actual: 0.070 m
# Recompensa Distancia: -0.070
# Recompensa Costo: -0.27924697399139403
# Recompensa diferencia: 0.016
# Recompensa llegada: 0.07038878373284604
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.2636138627154574
# --------------------------------------------------------------------
# Contador:  119
# Distancia previa : 0.070 m
# Distancia actual: 0.075 m
# Recompensa Distancia: -0.075
# Recompensa Costo: -0.2751039505004883
# Recompensa diferencia: -0.005
# Recompensa llegada: 0.07531072630446063
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.2800258930721029
# --------------------------------------------------------------------
# Contador:  120
# Distancia previa : 0.075 m
# Distancia actual: 0.083 m
# Recompensa Distancia: -0.083
# Recompensa Costo: -0.47505826950073243
# Recompensa diferencia: -0.008
# Recompensa llegada: 0.0829167073165265
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.4826642505127983
# --------------------------------------------------------------------
# Contador:  121
# Distancia previa : 0.083 m
# Distancia actual: 0.096 m
# Recompensa Distancia: -0.096
# Recompensa Costo: -0.3129555463790894
# Recompensa diferencia: -0.014
# Recompensa llegada: 0.09649458453809101
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3265334236006539
# --------------------------------------------------------------------
# Contador:  122
# Distancia previa : 0.096 m
# Distancia actual: 0.095 m
# Recompensa Distancia: -0.095
# Recompensa Costo: -0.4115278244018555
# Recompensa diferencia: 0.001
# Recompensa llegada: 0.09544482539397108
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.4104780652577355
# --------------------------------------------------------------------
# Contador:  123
# Distancia previa : 0.095 m
# Distancia actual: 0.092 m
# Recompensa Distancia: -0.092
# Recompensa Costo: -0.19629629850387575
# Recompensa diferencia: 0.004
# Recompensa llegada: 0.09158141345909095
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.19243288656899565
# --------------------------------------------------------------------
# Contador:  124
# Distancia previa : 0.092 m
# Distancia actual: 0.085 m
# Recompensa Distancia: -0.085
# Recompensa Costo: -0.15493828058242798
# Recompensa diferencia: 0.007
# Recompensa llegada: 0.08494319089908896
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.14830005802242602
# --------------------------------------------------------------------
# Contador:  125
# Distancia previa : 0.085 m
# Distancia actual: 0.088 m
# Recompensa Distancia: -0.088
# Recompensa Costo: -0.3788557291030884
# Recompensa diferencia: -0.003
# Recompensa llegada: 0.08832880078591195
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.38224133898991136
# --------------------------------------------------------------------
# Contador:  126
# Distancia previa : 0.088 m
# Distancia actual: 0.111 m
# Recompensa Distancia: -0.111
# Recompensa Costo: -0.41728172302246097
# Recompensa diferencia: -0.023
# Recompensa llegada: 0.11133644578877469
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.4402893680253238
# --------------------------------------------------------------------
# Contador:  127
# Distancia previa : 0.111 m
# Distancia actual: 0.096 m
# Recompensa Distancia: -0.096
# Recompensa Costo: -0.30287835597991947
# Recompensa diferencia: 0.015
# Recompensa llegada: 0.09625055573208764
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.28779246592323243
# --------------------------------------------------------------------
# Contador:  128
# Distancia previa : 0.096 m
# Distancia actual: 0.106 m
# Recompensa Distancia: -0.106
# Recompensa Costo: -0.37318651676177983
# Recompensa diferencia: -0.009
# Recompensa llegada: 0.10571310270033865
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3826490637300308
# --------------------------------------------------------------------
# Contador:  129
# Distancia previa : 0.106 m
# Distancia actual: 0.107 m
# Recompensa Distancia: -0.107
# Recompensa Costo: -0.37923517227172854
# Recompensa diferencia: -0.002
# Recompensa llegada: 0.10733101567489761
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3808530852462875
# --------------------------------------------------------------------
# Contador:  130
# Distancia previa : 0.107 m
# Distancia actual: 0.110 m
# Recompensa Distancia: -0.110
# Recompensa Costo: -0.363376259803772
# Recompensa diferencia: -0.003
# Recompensa llegada: 0.11018699326755735
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.36623223739643174
# --------------------------------------------------------------------
# Contador:  131
# Distancia previa : 0.110 m
# Distancia actual: 0.127 m
# Recompensa Distancia: -0.127
# Recompensa Costo: -0.3275206565856934
# Recompensa diferencia: -0.017
# Recompensa llegada: 0.12719059036078625
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.34452425367892237
# --------------------------------------------------------------------
# Contador:  132
# Distancia previa : 0.127 m
# Distancia actual: 0.127 m
# Recompensa Distancia: -0.127
# Recompensa Costo: -0.36629991531372075
# Recompensa diferencia: -0.000
# Recompensa llegada: 0.12736448601364056
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.36647381096657505
# --------------------------------------------------------------------
# Contador:  133
# Distancia previa : 0.127 m
# Distancia actual: 0.126 m
# Recompensa Distancia: -0.126
# Recompensa Costo: -0.43308486938476565
# Recompensa diferencia: 0.002
# Recompensa llegada: 0.12552402309926544
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.43124440647039053
# --------------------------------------------------------------------
# Contador:  134
# Distancia previa : 0.126 m
# Distancia actual: 0.128 m
# Recompensa Distancia: -0.128
# Recompensa Costo: -0.20644948482513428
# Recompensa diferencia: -0.003
# Recompensa llegada: 0.12812663185156872
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.20905209357743756
# --------------------------------------------------------------------
# Contador:  135
# Distancia previa : 0.128 m
# Distancia actual: 0.119 m
# Recompensa Distancia: -0.119
# Recompensa Costo: -0.33378579616546633
# Recompensa diferencia: 0.009
# Recompensa llegada: 0.11887449846366789
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3245336627775655
# --------------------------------------------------------------------
# Contador:  136
# Distancia previa : 0.119 m
# Distancia actual: 0.121 m
# Recompensa Distancia: -0.121
# Recompensa Costo: -0.34605414867401124
# Recompensa diferencia: -0.002
# Recompensa llegada: 0.12055087665971728
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.34773052687006056
# --------------------------------------------------------------------
# Contador:  137
# Distancia previa : 0.121 m

# %%
# Cargar el modelo guardado y evaluarlo por 25 episodios
import gymnasium   
import CoppeliaSim_Gym   # Entorno personalizado
import stable_baselines3   # Biblioteca RL
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3 import A2C, PPO  # Algoritmo RL
# Instancia del entorno
env = gymnasium.make("CoppeliaSim_Gym/GymCoppManR-v0")   
# Cargar el modelo guardado
model = PPO.load("modeloPPO", env=env)
# Inicializar la evaluacion del entorno
eval_env = gymnasium.make("CoppeliaSim_Gym/GymCoppManR-v0")
obs, inf = env.reset()
# Ejecutar el agente entrenado en 'eval_env' durante 25 pasos de tiempo y obtener la recompensa media
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes = 25, deterministic=False)

print(f"Recompensa media = {mean_reward:.2f} +/- {std_reward}")
# Out:
# Conectado al servidor API remoto
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Conectado al servidor API remoto
# C:\Users\USUARIO\anaconda3\envs\IAGen\Lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Contador:  1
# Distancia previa : 0.464 m
# Distancia actual: 0.461 m
# Recompensa Distancia: -0.461
# Recompensa Costo: -0.6763535499572755
# Recompensa diferencia: 0.003
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -1.1343604565054657
# --------------------------------------------------------------------
# Contador:  2
# Distancia previa : 0.458 m
# Distancia actual: 0.440 m
# Recompensa Distancia: -0.440
# Recompensa Costo: -0.40385060310363774
# Recompensa diferencia: 0.018
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.8259902939183477
# --------------------------------------------------------------------
# Contador:  3
# Distancia previa : 0.438 m
# Distancia actual: 0.439 m
# Recompensa Distancia: -0.439
# Recompensa Costo: -0.5935678482055664
# Recompensa diferencia: -0.001
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -1.0336685920018793
# --------------------------------------------------------------------
# Contador:  4
# Distancia previa : 0.436 m
# Distancia actual: 0.438 m
# Recompensa Distancia: -0.438
# Recompensa Costo: -0.37292912006378176
# Recompensa diferencia: -0.002
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.8123119197045658
# --------------------------------------------------------------------
# Contador:  5
# Distancia previa : 0.435 m
# Distancia actual: 0.425 m
# Recompensa Distancia: -0.425
# Recompensa Costo: -0.30261375904083254
# Recompensa diferencia: 0.009
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.7185723533508237
# --------------------------------------------------------------------
# Contador:  6
# Distancia previa : 0.422 m
# Distancia actual: 0.413 m
# Recompensa Distancia: -0.413
# Recompensa Costo: -0.3136098146438599
# Recompensa diferencia: 0.009
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.7180552401061018
# --------------------------------------------------------------------
# Contador:  7
# Distancia previa : 0.410 m
# Distancia actual: 0.399 m
# Recompensa Distancia: -0.399
# Recompensa Costo: -0.33151888847351074
# Recompensa diferencia: 0.012
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.7185119487299542
# --------------------------------------------------------------------
# Contador:  8
# Distancia previa : 0.396 m
# Distancia actual: 0.401 m
# Recompensa Distancia: -0.401
# Recompensa Costo: -0.4762895584106446
# Recompensa diferencia: -0.005
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.8819795441841431
# --------------------------------------------------------------------
# Contador:  9
# Distancia previa : 0.397 m
# Distancia actual: 0.377 m
# Recompensa Distancia: -0.377
# Recompensa Costo: -0.4250348091125489
# Recompensa diferencia: 0.021
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.7809295366199778
# --------------------------------------------------------------------
# Contador:  10
# Distancia previa : 0.373 m
# Distancia actual: 0.371 m
# Recompensa Distancia: -0.371
# Recompensa Costo: -0.41280431747436525
# Recompensa diferencia: 0.003
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.7810869321434442
# --------------------------------------------------------------------
# Contador:  11
# Distancia previa : 0.368 m
# Distancia actual: 0.348 m
# Recompensa Distancia: -0.348
# Recompensa Costo: -0.26698424816131594
# Recompensa diferencia: 0.019
# Recompensa llegada: 0.34817202937414626
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.24764497170354016
# --------------------------------------------------------------------
# Contador:  12
# Distancia previa : 0.345 m
# Distancia actual: 0.341 m
# Recompensa Distancia: -0.341
# Recompensa Costo: -0.3078419446945191
# Recompensa diferencia: 0.004
# Recompensa llegada: 0.34068891806793916
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.3037527372844014
# --------------------------------------------------------------------
# Contador:  13
# Distancia previa : 0.337 m
# Distancia actual: 0.353 m
# Recompensa Distancia: -0.353
# Recompensa Costo: -0.45055813789367677
# Recompensa diferencia: -0.016
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.8202285932362829
# --------------------------------------------------------------------
# Contador:  14
# Distancia previa : 0.350 m
# Distancia actual: 0.351 m
# Recompensa Distancia: -0.351
# Recompensa Costo: -0.17807613611221315
# Recompensa diferencia: -0.001
# Recompensa llegada: 0.0
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.5302933637248497
# --------------------------------------------------------------------
# Contador:  15
# Distancia previa : 0.348 m
# Distancia actual: 0.350 m
# Recompensa Distancia: -0.350
# Recompensa Costo: -0.35213513374328614
# Recompensa diferencia: -0.002
# Recompensa llegada: 0.34976577341647197
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.35428287557462046
# --------------------------------------------------------------------
# Contador:  16
# Distancia previa : 0.346 m
# Distancia actual: 0.334 m
# Recompensa Distancia: -0.334
# Recompensa Costo: -0.27631516456604005
# Recompensa diferencia: 0.012
# Recompensa llegada: 0.33419858728693097
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.26426908853890996
# --------------------------------------------------------------------
# Contador:  17
# Distancia previa : 0.331 m
# Distancia actual: 0.325 m
# Recompensa Distancia: -0.325
# Recompensa Costo: -0.2918645143508911
# Recompensa diferencia: 0.005
# Recompensa llegada: 0.3251332479794957
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.28639441781706987
# --------------------------------------------------------------------
# Contador:  18
# Distancia previa : 0.322 m
# Distancia actual: 0.317 m
# Recompensa Distancia: -0.317
# Recompensa Costo: -0.3719141244888306
# Recompensa diferencia: 0.005
# Recompensa llegada: 0.3167731445615174
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.36708298939216455
# --------------------------------------------------------------------
# Contador:  19
# Distancia previa : 0.313 m
# Distancia actual: 0.315 m
# Recompensa Distancia: -0.315
# Recompensa Costo: -0.1921148180961609
# Recompensa diferencia: -0.002
# Recompensa llegada: 0.3148896072270687
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.19389859675958065
# --------------------------------------------------------------------
# Contador:  20
# Distancia previa : 0.311 m
# Distancia actual: 0.296 m
# Recompensa Distancia: -0.296
# Recompensa Costo: -0.30785179138183594
# Recompensa diferencia: 0.015
# Recompensa llegada: 0.2963044300965297
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.2929265530431278
# --------------------------------------------------------------------
# Contador:  21
# Distancia previa : 0.293 m
# Distancia actual: 0.285 m
# Recompensa Distancia: -0.285
# Recompensa Costo: -0.44372282028198246
# Recompensa diferencia: 0.008
# Recompensa llegada: 0.2850620605307678
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.43621855722830977
# --------------------------------------------------------------------
# Contador:  22
# Distancia previa : 0.281 m
# Distancia actual: 0.287 m
# Recompensa Distancia: -0.287
# Recompensa Costo: -0.49158864021301274
# Recompensa diferencia: -0.005
# Recompensa llegada: 0.28659845352338675
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.49691008710439366
# --------------------------------------------------------------------
# Contador:  23
# Distancia previa : 0.283 m
# Distancia actual: 0.275 m
# Recompensa Distancia: -0.275
# Recompensa Costo: -0.23965997695922853
# Recompensa diferencia: 0.007
# Recompensa llegada: 0.27529824609796827
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.2322515369101168
# --------------------------------------------------------------------
# Contador:  24
# Distancia previa : 0.271 m
# Distancia actual: 0.276 m
# Recompensa Distancia: -0.276
# Recompensa Costo: -0.5167926788330078
# Recompensa diferencia: -0.005
# Recompensa llegada: 0.2759929306555862
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.5213493347800848
# --------------------------------------------------------------------
# Contador:  25
# Distancia previa : 0.272 m
# Distancia actual: 0.276 m
# Recompensa Distancia: -0.276
# Recompensa Costo: -0.18235993385314941
# Recompensa diferencia: -0.004
# Recompensa llegada: 0.27602098684975307
# No hay colision!
# No hay colision!
# Recompensa Colision: 0.0
# Recompensa Total:  -0.18618151803190314
# --------------------------------------------------------------------
# Recompensa media = -0.56 +/- 0.276559259612596
