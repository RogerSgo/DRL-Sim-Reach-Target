# %%
import gymnasium 
import numpy as np
import matplotlib.pyplot as plt
#import time
import CoppeliaSim_Gym # entorno
import stable_baselines3
# print(f"{gymnasium.__version__=}")
from stable_baselines3.common.env_checker import check_env # verificar el entorno

# %%
ENV_NAME = "CoppeliaSim_Gym/GymCoppManR-v0"
env = gymnasium.make(ENV_NAME) 
#check_env(env, warn=True) # si funciona
# Out:
# Conectado al servidor API remoto

# %%
print("Espacio de observacion:", env.observation_space)
print("Shape Obs:", env.observation_space.shape) 
print("tipo de observacion:", env.observation_space.dtype) 
#print("Sample Obs:", env.observation_space.sample())
print("Espacio de accion:", env.action_space)
print(env.joint_angles())
print("Action space sample:", env.action_space.sample())
print("Estado:", env.estado())
print('dist', env.distance_to_goal())
# Out:
# Espacio de observacion: Box(-180.0, 180.0, (18,), float32)
# Shape Obs: (18,)
# tipo de observacion: float32
# Espacio de accion: Box(-1.0, 1.0, (7,), float32)
# [-1.5854790e-04  4.2149685e-03  0.0000000e+00 -1.5715578e+00
#  -1.0224087e-04  1.5707474e+00 -8.8817842e-16]
# Action space sample: [-0.8593232   0.18165268 -0.6715974  -0.26913166 -0.31855822  0.7077488
#  -0.71331865]
# Estado: [ 1.0553489e+00  7.9770666e-04  5.0776106e-01 -1.5854790e-04
#   1.0000000e+00  4.2149560e-03  9.9999112e-01  0.0000000e+00
#   1.0000000e+00 -9.9999970e-01 -7.6143339e-04 -1.0224087e-04
#   1.0000000e+00  1.0000000e+00  4.8951308e-05 -8.8817842e-16
#   1.0000000e+00  4.8279136e-01]
# dist 0.48279136

# %%
# Evaluar sistema con acciones aleatorias
acc=[]
X_ = []
Y_ = []
env.reset()
for episode in range(25):
    env.render()
    # toma una accion aleatoria
    env.step(env.action_space.sample()) 
    score = env.comp_reward()
    print(f'Episode: {episode} Score: {score}')
    #time.sleep(5)
    acc += [env.distance_to_goal()]
    X_.append(episode)
    Y_.append(np.array(acc).mean())
plt.plot(X_, Y_)
plt.title('Distancia medida')
plt.xlabel('Num Episodios')
plt.ylabel('Distancia O-EF')
plt.show()
env.close()
# Out:
# C:\Users\USUARIO\anaconda3\envs\IAGen\Lib\site-packages\gymnasium\utils\passive_env_checker.py:188: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# Contador:  1
# Distancia previa : 0.531 m
# Posicion efector final:  1.0074488 -0.06349182 0.6072876
# Posicion objetivo:  0.66772324 -0.04384607 0.14518414
# Distancia actual: 0.831 m
# Recompensa distancia: -0.300
# Recompensa llegada: 0.0
# El efector y el objeto no están colisionando
# El efector y el objeto no están colisionando
# Recompensa Colision: 0.0
# Recompensa Total:  -0.30319270316119545
# --------------------------------------------------------------------
# Episode: 0 Score: 0
# C:\Users\USUARIO\anaconda3\envs\IAGen\Lib\site-packages\gymnasium\utils\passive_env_checker.py:188: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# Contador:  2
# Distancia previa : 0.831 m
# Posicion efector final:  0.2021819 -0.21048397 0.762596
# Posicion objetivo:  0.66772324 -0.04384607 0.14518414
# Distancia actual: 0.669 m
# Recompensa distancia: 0.163
# Recompensa llegada: 0.0
# El efector y el objeto no están colisionando
# El efector y el objeto no están colisionando
# Recompensa Colision: 0.0
# Recompensa Total:  0.16130597411948253
# --------------------------------------------------------------------
# Episode: 1 Score: 0
# Contador:  3
# Distancia previa : 0.669 m
# Posicion efector final:  0.6885749 -0.028182514 0.91292155
# Posicion objetivo:  0.66772324 -0.04384607 0.14518414
# Distancia actual: 0.862 m
# Recompensa distancia: -0.193
# Recompensa llegada: 0.0
# El efector y el objeto no están colisionando
# El efector y el objeto no están colisionando
# Recompensa Colision: 0.0
# Recompensa Total:  -0.1966340158828237
# --------------------------------------------------------------------
# Episode: 2 Score: 0
# Contador:  4
# Distancia previa : 0.862 m
# Posicion efector final:  0.47861108 -0.3229986 0.8593888
# Posicion objetivo:  0.66772324 -0.04384607 0.14518414
# Distancia actual: 0.689 m
# Recompensa distancia: 0.173
# Recompensa llegada: 0.0
# El efector y el objeto no están colisionando
# El efector y el objeto no están colisionando
# Recompensa Colision: 0.0
# Recompensa Total:  0.16888776230498675
# --------------------------------------------------------------------
# Episode: 3 Score: 0
# Contador:  5
# Distancia previa : 0.689 m
# Posicion efector final:  0.6204821 -0.24740322 0.73288655
# Posicion objetivo:  0.66772324 -0.04384607 0.14518414
# Distancia actual: 0.624 m
# Recompensa distancia: 0.065
# Recompensa llegada: 0.0
# El efector y el objeto no están colisionando
# El efector y el objeto no están colisionando
# Recompensa Colision: 0.0
# Recompensa Total:  0.06344222166409089
# --------------------------------------------------------------------
# Episode: 4 Score: 0
# Contador:  6
# Distancia previa : 0.624 m
# Posicion efector final:  0.6200806 0.2145502 0.7541607
# Posicion objetivo:  0.66772324 -0.04384607 0.14518414
# Distancia actual: 0.716 m
# Recompensa distancia: -0.092
# Recompensa llegada: 0.0
# El efector y el objeto no están colisionando
# El efector y el objeto no están colisionando
# Recompensa Colision: 0.0
# Recompensa Total:  -0.09560875531838672
# --------------------------------------------------------------------
# Episode: 5 Score: 0
# Contador:  7
# Distancia previa : 0.716 m
# Posicion efector final:  0.27099523 0.0048973584 0.8314013
# Posicion objetivo:  0.66772324 -0.04384607 0.14518414
# Distancia actual: 0.906 m
# Recompensa distancia: -0.190
# Recompensa llegada: 0.0
# El efector y el objeto no están colisionando
# El efector y el objeto no están colisionando
# Recompensa Colision: 0.0
# Recompensa Total:  -0.19321565575372762
# --------------------------------------------------------------------
# Episode: 6 Score: 0
# Contador:  8
# Distancia previa : 0.906 m
# Posicion efector final:  0.40100655 -0.09672852 0.9125243
# Posicion objetivo:  0.66772324 -0.04384607 0.14518414
# Distancia actual: 0.609 m
# Recompensa distancia: 0.297
# Recompensa llegada: 0.0
# El efector y el objeto no están colisionando
# El efector y el objeto no están colisionando
# Recompensa Colision: 0.0
# Recompensa Total:  0.2941146369687538
# --------------------------------------------------------------------
# Episode: 7 Score: 0
# Contador:  9
# Distancia previa : 0.609 m
# Posicion efector final:  0.8162219 -0.20315444 0.7004861
# Posicion objetivo:  0.66772324 -0.04384607 0.14518414
# Distancia actual: 0.726 m
# Recompensa distancia: -0.117
# Recompensa llegada: 0.0
# El efector y el objeto no están colisionando
# El efector y el objeto no están colisionando
# Recompensa Colision: 0.0
# Recompensa Total:  -0.11741078622990503
# --------------------------------------------------------------------
# Episode: 8 Score: 0
# Contador:  10
# Distancia previa : 0.726 m
# Posicion efector final:  0.47226337 -0.029148579 0.8633923
# Posicion objetivo:  0.66772324 -0.04384607 0.14518414
# Distancia actual: 0.607 m
# Recompensa distancia: 0.119
# Recompensa llegada: 0.0
# El efector y el objeto no están colisionando
# El efector y el objeto no están colisionando
# Recompensa Colision: 0.0
# Recompensa Total:  0.11639271826722888
# --------------------------------------------------------------------
# Episode: 9 Score: 0
# Contador:  11
# Distancia previa : 0.607 m
# Posicion efector final:  0.9675016 -0.2522033 0.60510224
# Posicion objetivo:  0.66772324 -0.04384607 0.14518414
# Distancia actual: 0.605 m
# Recompensa distancia: 0.002
# Recompensa llegada: 0.0
# El efector y el objeto no están colisionando
# El efector y el objeto no están colisionando
# Recompensa Colision: 0.0
# Recompensa Total:  0.0003871013697964072
# --------------------------------------------------------------------
# Episode: 10 Score: 0
# Contador:  12
# Distancia previa : 0.605 m
# Posicion efector final:  0.9080855 0.19964159 0.63661355
# Posicion objetivo:  0.66772324 -0.04384607 0.14518414
# Distancia actual: 0.713 m
# Recompensa distancia: -0.108
# Recompensa llegada: 0.0
# El efector y el objeto no están colisionando
# El efector y el objeto no están colisionando
# Recompensa Colision: 0.0
# Recompensa Total:  -0.11034634426396929
# --------------------------------------------------------------------
# Episode: 11 Score: 0
# Contador:  13
# Distancia previa : 0.713 m
# Posicion efector final:  0.43838856 -0.12907645 0.80232394
# Posicion objetivo:  0.66772324 -0.04384607 0.14518414
# Distancia actual: 0.664 m
# Recompensa distancia: 0.048
# Recompensa llegada: 0.0
# El efector y el objeto no están colisionando
# El efector y el objeto no están colisionando
# Recompensa Colision: 0.0
# Recompensa Total:  0.0464006215501922
# --------------------------------------------------------------------
# Episode: 12 Score: 0
# Contador:  14
# Distancia previa : 0.664 m
# Posicion efector final:  0.6884006 -0.004199473 0.7892502
# Posicion objetivo:  0.66772324 -0.04384607 0.14518414
# Distancia actual: 0.596 m
# Recompensa distancia: 0.068
# Recompensa llegada: 0.0
# El efector y el objeto no están colisionando
# El efector y el objeto no están colisionando
# Recompensa Colision: 0.0
# Recompensa Total:  0.06478719709291972
# --------------------------------------------------------------------
# Episode: 13 Score: 0
# Contador:  15
# Distancia previa : 0.596 m
# Posicion efector final:  1.0019373 0.10272827 0.48641658
# Posicion objetivo:  0.66772324 -0.04384607 0.14518414
# Distancia actual: 0.560 m
# Recompensa distancia: 0.036
# Recompensa llegada: 0.0
# El efector y el objeto no están colisionando
# El efector y el objeto no están colisionando
# Recompensa Colision: 0.0
# Recompensa Total:  0.03374300639186074
# --------------------------------------------------------------------
# Episode: 14 Score: 0
# Contador:  16
# Distancia previa : 0.560 m
# Posicion efector final:  0.784781 -0.37564465 0.57304746
# Posicion objetivo:  0.66772324 -0.04384607 0.14518414
# Distancia actual: 0.759 m
# Recompensa distancia: -0.199
# Recompensa llegada: 0.0
# El efector y el objeto no están colisionando
# El efector y el objeto no están colisionando
# Recompensa Colision: 0.0
# Recompensa Total:  -0.2016521417697447
# --------------------------------------------------------------------
# Episode: 15 Score: 0
# Contador:  17
# Distancia previa : 0.759 m
# Posicion efector final:  0.21416222 0.20606272 0.67466176
# Posicion objetivo:  0.66772324 -0.04384607 0.14518414
# Distancia actual: 0.738 m
# Recompensa distancia: 0.020
# Recompensa llegada: 0.0
# El efector y el objeto no están colisionando
# El efector y el objeto no están colisionando
# Recompensa Colision: 0.0
# Recompensa Total:  0.016983309746297474
# --------------------------------------------------------------------
# Episode: 16 Score: 0
# Contador:  18
# Distancia previa : 0.738 m
# Posicion efector final:  0.28880662 -0.16734242 0.73542666
# Posicion objetivo:  0.66772324 -0.04384607 0.14518414
# Distancia actual: 0.700 m
# Recompensa distancia: 0.039
# Recompensa llegada: 0.0
# El efector y el objeto no están colisionando
# El efector y el objeto no están colisionando
# Recompensa Colision: 0.0
# Recompensa Total:  0.037132626919760624
# --------------------------------------------------------------------
# Episode: 17 Score: 0
# Contador:  19
# Distancia previa : 0.700 m
# Posicion efector final:  0.444157 0.09697361 0.8567975
# Posicion objetivo:  0.66772324 -0.04384607 0.14518414
# Distancia actual: 0.898 m
# Recompensa distancia: -0.198
# Recompensa llegada: 0.0
# El efector y el objeto no están colisionando
# El efector y el objeto no están colisionando
# Recompensa Colision: 0.0
# Recompensa Total:  -0.19978168365603324
# --------------------------------------------------------------------
# Episode: 18 Score: 0
# Contador:  20
# Distancia previa : 0.898 m
# Posicion efector final:  0.318745 -0.031502 0.91292477
# Posicion objetivo:  0.66772324 -0.04384607 0.14518414
# Distancia actual: 0.746 m
# Recompensa distancia: 0.152
# Recompensa llegada: 0.0
# El efector y el objeto no están colisionando
# El efector y el objeto no están colisionando
# Recompensa Colision: 0.0
# Recompensa Total:  0.15017899779003416
# --------------------------------------------------------------------
# Episode: 19 Score: 0
# Contador:  21
# Distancia previa : 0.746 m
# Posicion efector final:  0.31746167 0.12433156 0.8012949
# Posicion objetivo:  0.66772324 -0.04384607 0.14518414
# Distancia actual: 0.812 m
# Recompensa distancia: -0.066
# Recompensa llegada: 0.0
# El efector y el objeto no están colisionando
# El efector y el objeto no están colisionando
# Recompensa Colision: 0.0
# Recompensa Total:  -0.0680989292223146
# --------------------------------------------------------------------
# Episode: 20 Score: 0
# Contador:  22
# Distancia previa : 0.812 m
# Posicion efector final:  0.4712112 0.25097162 0.9308405
# Posicion objetivo:  0.66772324 -0.04384607 0.14518414
# Distancia actual: 0.893 m
# Recompensa distancia: -0.081
# Recompensa llegada: 0.0
# El efector y el objeto no están colisionando
# El efector y el objeto no están colisionando
# Recompensa Colision: 0.0
# Recompensa Total:  -0.08440501020064915
# --------------------------------------------------------------------
# Episode: 21 Score: 0
# Contador:  23
# Distancia previa : 0.893 m
# Posicion efector final:  0.29487088 0.1300545 0.8369083
# Posicion objetivo:  0.66772324 -0.04384607 0.14518414
# Distancia actual: 0.759 m
# Recompensa distancia: 0.133
# Recompensa llegada: 0.0
# El efector y el objeto no están colisionando
# El efector y el objeto no están colisionando
# Recompensa Colision: 0.0
# Recompensa Total:  0.13144281640037989
# --------------------------------------------------------------------
# Episode: 22 Score: 0
# Contador:  24
# Distancia previa : 0.759 m
# Posicion efector final:  0.45013624 -0.016324975 0.9615628
# Posicion objetivo:  0.66772324 -0.04384607 0.14518414
# Distancia actual: 0.895 m
# Recompensa distancia: -0.136
# Recompensa llegada: 0.0
# El efector y el objeto no están colisionando
# El efector y el objeto no están colisionando
# Recompensa Colision: 0.0
# Recompensa Total:  -0.13928089770507232
# --------------------------------------------------------------------
# Episode: 23 Score: 0
# Contador:  25
# Distancia previa : 0.895 m
# Posicion efector final:  0.392218 -0.22059222 0.9258921
# Posicion objetivo:  0.66772324 -0.04384607 0.14518414
# Distancia actual: 0.816 m
# Recompensa distancia: 0.079
# Recompensa llegada: 0.0
# El efector y el objeto no están colisionando
# El efector y el objeto no están colisionando
# Recompensa Colision: 0.0
# Recompensa Total:  0.0747334523806693
# --------------------------------------------------------------------
# Episode: 24 Score: 0
